# %% [markdown]
# #TASK #1: PROJECT OVERVIEW AND ASSET TYPES

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1TEVVCFWQD8F5mlC7FzD-JM2y54ivYZHT)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1Z253Wmij7HCEHqPsMdEI56qYqASRrsjn)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=10XxwtKY2qEiNAdTkqNXKhNFZrWvwwKbN)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1SfBtfOoDigo4ofEvPAwIojqGHpMojL5S)

# %% [markdown]
# Links:
# - https://www.bankofcanada.ca/rates/interest-rates/canadian-bonds/
# - https://ca.finance.yahoo.com/quote/AAPL?p=AAPL&.tsrc=fin-tre-srch
# - https://investor.vanguard.com/etf/profile/performance/voo
# - https://grow.acorns.com/warren-buffett-index-funds/

# %% [markdown]
# # TASK #2: IMPORT LIBRARIES & DATASETS AND PERFORM DATA VISUALIZATION

# %%
import pandas as pd
import plotly.express as px
from copy import copy
from scipy import stats
import matplotlib.pyplot as plt
import numpy as np
import plotly.figure_factory as ff
import plotly.graph_objects as go

# %%
# Read the stock data file
stocks_df = pd.read_csv('/content/stock.csv')
stocks_df
# Out:
#             Date        AAPL          BA  ...         TSLA         GOOG        sp500
# 0     2012-01-12   60.198570   75.510002  ...    28.250000   313.644379  1295.500000
# 1     2012-01-13   59.972858   74.599998  ...    22.790001   311.328064  1289.089966
# 2     2012-01-17   60.671429   75.239998  ...    26.600000   313.116364  1293.670044
# 3     2012-01-18   61.301430   75.059998  ...    26.809999   315.273285  1308.040039
# 4     2012-01-19   61.107143   75.559998  ...    26.760000   318.590851  1314.500000
# ...          ...         ...         ...  ...          ...          ...          ...
# 2154  2020-08-05  440.250000  174.279999  ...  1485.020020  1473.609985  3327.770020
# 2155  2020-08-06  455.609985  172.199997  ...  1489.579956  1500.099976  3349.159912
# 2156  2020-08-07  444.450012  170.020004  ...  1452.709961  1494.489990  3351.280029
# 2157  2020-08-10  450.910004  179.410004  ...  1418.569946  1496.099976  3360.469971
# 2158  2020-08-11  437.500000  180.130005  ...  1374.390015  1480.319946  3333.689941
#
# [2159 rows x 10 columns]

# %%
# Sort the data based on Date
stocks_df.sort_values(by=['Date'])
# Out:
#             Date        AAPL          BA  ...         TSLA         GOOG        sp500
# 0     2012-01-12   60.198570   75.510002  ...    28.250000   313.644379  1295.500000
# 1     2012-01-13   59.972858   74.599998  ...    22.790001   311.328064  1289.089966
# 2     2012-01-17   60.671429   75.239998  ...    26.600000   313.116364  1293.670044
# 3     2012-01-18   61.301430   75.059998  ...    26.809999   315.273285  1308.040039
# 4     2012-01-19   61.107143   75.559998  ...    26.760000   318.590851  1314.500000
# ...          ...         ...         ...  ...          ...          ...          ...
# 2154  2020-08-05  440.250000  174.279999  ...  1485.020020  1473.609985  3327.770020
# 2155  2020-08-06  455.609985  172.199997  ...  1489.579956  1500.099976  3349.159912
# 2156  2020-08-07  444.450012  170.020004  ...  1452.709961  1494.489990  3351.280029
# 2157  2020-08-10  450.910004  179.410004  ...  1418.569946  1496.099976  3360.469971
# 2158  2020-08-11  437.500000  180.130005  ...  1374.390015  1480.319946  3333.689941
#
# [2159 rows x 10 columns]

# %% [markdown]
# **MINI CHALLENGE #1:**
# - **Use Plotly express to visualize raw stock data and normalized ones**

# %%
# def show_plot(df, fig_title):
#   df.plot(x=df['Date'], figsize(15, 8), title=fig_title)
#   plt.grid()
#   plt.show()

# %%
# show_plot(stocks_df, 'Stock Prices - Raw data')

# %%
def normalization(df):
  norm_df = df.copy()
  for i in df.columns[1:]:
    norm_df[i] = norm_df[i] / norm_df[i][0]
  return norm_df

# %%
# show_plot(normalization(stocks_df), 'Stock Prices - Normalazed data')

# %%
def interactive_plot(df, title):
  fig = px.line(title=title)

  for i in df.columns[1:]:
    fig.add_scatter(x=df['Date'], y=df[i], name=i)

  return fig

# %%
interactive_plot(normalization(stocks_df), 'Normalized Stock Prices in Interactive View')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d0822366-1021-4515-96e0-9879ff509f09" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d0822366-1021-4515-96e0-9879ff509f09")) {
#                     Plotly.newPlot(
#                         'd0822366-1021-4515-96e0-9879ff509f09',
#                         [{"name": "AAPL", "type": "scatter", "x": ["2012-01-12", "2012-01-13", "2012-01-17", "2012-01-18", "2012-01-19", "2012-01-20", "2012-01-23", "2012-01-24", "2012-01-25", "2012-01-26", "2012-01-27", "2012-01-30", "2012-01-31", "2012-02-01", "2012-02-02", "2012-02-03", "2012-02-06", "2012-02-07", "2012-02-08", "2012-02-09", "2012-02-10", "2012-02-13", "2012-02-14", "2012-02-15", "2012-02-16", "2012-02-17", "2012-02-21", "2012-02-22", "2012-02-23", "2012-02-24", "2012-02-27", "2012-02-28", "2012-02-29", "2012-03-01", "2012-03-02", "2012-03-05", "2012-03-06", "2012-03-07", "2012-03-08", "2012-03-09", "2012-03-12", "2012-03-13", "2012-03-14", "2012-03-15", "2012-03-16", "2012-03-19", "2012-03-20", "2012-03-21", "2012-03-22", "2012-03-23", "2012-03-26", "2012-03-27", "2012-03-28", "2012-03-29", "2012-03-30", "2012-04-02", "2012-04-03", "2012-04-04", "2012-04-05", "2012-04-09", "2012-04-10", "2012-04-11", "2012-04-12", "2012-04-13", "2012-04-16", "2012-04-17", "2012-04-18", "2012-04-19", "2012-04-20", "2012-04-23", "2012-04-24", "2012-04-25", "2012-04-26", "2012-04-27", "2012-04-30", "2012-05-01", "2012-05-02", "2012-05-03", "2012-05-04", "2012-05-07", "2012-05-08", "2012-05-09", "2012-05-10", "2012-05-11", "2012-05-14", "2012-05-15", "2012-05-16", "2012-05-17", "2012-05-18", "2012-05-21", "2012-05-22", "2012-05-23", "2012-05-24", "2012-05-25", "2012-05-29", "2012-05-30", "2012-05-31", "2012-06-01", "2012-06-04", "2012-06-05", "2012-06-06", "2012-06-07", "2012-06-08", "2012-06-11", "2012-06-12", "2012-06-13", "2012-06-14", "2012-06-15", "2012-06-18", "2012-06-19", "2012-06-20", "2012-06-21", "2012-06-22", "2012-06-25", "2012-06-26", "2012-06-27", "2012-06-28", "2012-06-29", "2012-07-02", "2012-07-03", "2012-07-05", "2012-07-06", "2012-07-09", "2012-07-10", "2012-07-11", "2012-07-12", "2012-07-13", "2012-07-16", "2012-07-17", "2012-07-18", "2012-07-19", "2012-07-20", "2012-07-23", "2012-07-24", "2012-07-25", "2012-07-26", "2012-07-27", "2012-07-30", "2012-07-31", "2012-08-01", "2012-08-02", "2012-08-03", "2012-08-06", "2012-08-07", "2012-08-08", "2012-08-09", "2012-08-10", "2012-08-13", "2012-08-14", "2012-08-15", "2012-08-16", "2012-08-17", "2012-08-20", "2012-08-21", "2012-08-22", "2012-08-23", "2012-08-24", "2012-08-27", "2012-08-28", "2012-08-29", "2012-08-30", "2012-08-31", "2012-09-04", "2012-09-05", "2012-09-06", "2012-09-07", "2012-09-10", "2012-09-11", "2012-09-12", "2012-09-13", "2012-09-14", "2012-09-17", "2012-09-18", "2012-09-19", "2012-09-20", "2012-09-21", "2012-09-24", "2012-09-25", "2012-09-26", "2012-09-27", "2012-09-28", "2012-10-01", "2012-10-02", "2012-10-03", "2012-10-04", "2012-10-05", "2012-10-08", "2012-10-09", "2012-10-10", "2012-10-11", "2012-10-12", "2012-10-15", "2012-10-16", "2012-10-17", "2012-10-18", "2012-10-19", "2012-10-22", "2012-10-23", "2012-10-24", "2012-10-25", "2012-10-26", "2012-10-31", "2012-11-01", "2012-11-02", "2012-11-05", "2012-11-06", "2012-11-07", "2012-11-08", "2012-11-09", "2012-11-12", "2012-11-13", "2012-11-14", "2012-11-15", "2012-11-16", "2012-11-19", "2012-11-20", "2012-11-21", "2012-11-23", "2012-11-26", "2012-11-27", "2012-11-28", "2012-11-29", "2012-11-30", "2012-12-03", "2012-12-04", "2012-12-05", "2012-12-06", "2012-12-07", "2012-12-10", "2012-12-11", "2012-12-12", "2012-12-13", "2012-12-14", "2012-12-17", "2012-12-18", "2012-12-19", "2012-12-20", "2012-12-21", "2012-12-24", "2012-12-26", "2012-12-27", "2012-12-28", "2012-12-31", "2013-01-02", "2013-01-03", "2013-01-04", "2013-01-07", "2013-01-08", "2013-01-09", "2013-01-10", "2013-01-11", "2013-01-14", "2013-01-15", "2013-01-16", "2013-01-17", "2013-01-18", "2013-01-22", "2013-01-23", "2013-01-24", "2013-01-25", "2013-01-28", "2013-01-29", "2013-01-30", "2013-01-31", "2013-02-01", "2013-02-04", "2013-02-05", "2013-02-06", "2013-02-07", "2013-02-08", "2013-02-11", "2013-02-12", "2013-02-13", "2013-02-14", "2013-02-15", "2013-02-19", "2013-02-20", "2013-02-21", "2013-02-22", "2013-02-25", "2013-02-26", ...

# %% [markdown]
# # TASK #3: UNERSTAND THE CONCEPT OF ASSET ALLOCATION

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=17SLLaxLeP6vlXH6MltEQMFNbt5u-J6iK)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1qLML-ejBIKR8Bv8aeItfNaJuhq5GzvJ5)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1iR3WYvU9SYVRqhKwR91x0AsE5sGQtFhz)

# %% [markdown]
# **MINI CHALLENGE #2:**
# - **What is the common advice that financial advisors generally give to retired seniors when it comes to asset allocations?**

# %%
# Retirement: 70s and 80s
# Sample Asset Allocation:

# Stocks: 30% to 50%
# Bonds: 50% to 70%

# %%
# The conventional wisdom is to subtract client's age from 100 to calculate the % of portolio that should be allocated to stocks
# For Example: If you're 30 years old, you should have 70% allocated to stocks
# If you are 75 years old, you should invest 25% in stocks (old retired seniors generally recommend a more stable low risk portfolio).

# %% [markdown]
# # TASK #4: PERFORM RANDOM ASSET ALLOCATION AND CALCULATE PORTFOLIO DAILY RETURN

# %%
# Let's create random portfolio weights
# Portfolio weights must sum to 1

# Set random seed
np.random.seed(101)

# %%
# Create random weight for the stocks and normalize them
weights = np.array(np.random.random(9))
weights
# Out:
# array([0.51639863, 0.57066759, 0.02847423, 0.17152166, 0.68527698,
#        0.83389686, 0.30696622, 0.89361308, 0.72154386])

# %%
# Ensure that the sum of all weights are = 1
weights = weights / np.sum(weights)
print(weights)
# Out:
# [0.10921307 0.12069041 0.00602201 0.03627509 0.14492913 0.17636073
#  0.06492024 0.1889901  0.15259921]

# %%
# Normalize the stock avalues 
df_portfolio = normalization(stocks_df)
df_portfolio
# Out:
#             Date      AAPL        BA  ...       TSLA      GOOG     sp500
# 0     2012-01-12  1.000000  1.000000  ...   1.000000  1.000000  1.000000
# 1     2012-01-13  0.996251  0.987949  ...   0.806726  0.992615  0.995052
# 2     2012-01-17  1.007855  0.996424  ...   0.941593  0.998317  0.998587
# 3     2012-01-18  1.018320  0.994040  ...   0.949027  1.005193  1.009680
# 4     2012-01-19  1.015093  1.000662  ...   0.947257  1.015771  1.014666
# ...          ...       ...       ...  ...        ...       ...       ...
# 2154  2020-08-05  7.313297  2.308039  ...  52.567080  4.698347  2.568715
# 2155  2020-08-06  7.568452  2.280493  ...  52.728494  4.782805  2.585226
# 2156  2020-08-07  7.383066  2.251622  ...  51.423361  4.764919  2.586862
# 2157  2020-08-10  7.490377  2.375977  ...  50.214865  4.770052  2.593956
# 2158  2020-08-11  7.267614  2.385512  ...  48.650974  4.719740  2.573284
#
# [2159 rows x 10 columns]

# %%
df_portfolio.columns[1:]
# Out:
# Index(['AAPL', 'BA', 'T', 'MGM', 'AMZN', 'IBM', 'TSLA', 'GOOG', 'sp500'], dtype='object')

# %%
# Note that enumerate returns the value and a counter as well
for counter, stock in enumerate(df_portfolio.columns[1:]):
  df_portfolio[stock] = df_portfolio[stock] * weights[counter]
  df_portfolio[stock] = df_portfolio[stock] * 1000000

df_portfolio
# Out:
#             Date           AAPL  ...           GOOG          sp500
# 0     2012-01-12  109213.072967  ...  188990.104235  152599.209597
# 1     2012-01-13  108803.583155  ...  187594.381427  151844.160487
# 2     2012-01-17  110070.940263  ...  188671.942595  152383.655881
# 3     2012-01-18  111213.896735  ...  189971.620676  154076.322712
# 4     2012-01-19  110861.418590  ...  191970.659033  154837.252810
# ...          ...            ...  ...            ...            ...
# 2154  2020-08-05  798707.600095  ...  887941.003611  391983.847760
# 2155  2020-08-06  826573.895966  ...  903902.858806  394503.400529
# 2156  2020-08-07  806327.319584  ...  900522.495854  394753.132817
# 2157  2020-08-10  818047.125846  ...  901492.611827  395835.632149
# 2158  2020-08-11  793718.512304  ...  891984.169418  392681.165603
#
# [2159 rows x 10 columns]

# %%
# Let's create an additional column that contains the sum of all $ values in the portfolio
df_portfolio['sum of all $ values (portfolio daily worth in $)'] = df_portfolio[df_portfolio != 'Date'].sum(axis=1)
df_portfolio
# Out:
#             Date  ...  sum of all $ values (portfolio daily worth in $)
# 0     2012-01-12  ...                                      1.000000e+06
# 1     2012-01-13  ...                                      9.847792e+05
# 2     2012-01-17  ...                                      1.000669e+06
# 3     2012-01-18  ...                                      1.013905e+06
# 4     2012-01-19  ...                                      1.020814e+06
# ...          ...  ...                                               ...
# 2154  2020-08-05  ...                                      8.588634e+06
# 2155  2020-08-06  ...                                      8.664444e+06
# 2156  2020-08-07  ...                                      8.506059e+06
# 2157  2020-08-10  ...                                      8.450456e+06
# 2158  2020-08-11  ...                                      8.256690e+06
#
# [2159 rows x 11 columns]

# %%
# Let's calculate the portfolio daily return 
# Define a new column in the dataframe and set it to zeros

df_portfolio['portfolio daily % return'] = 0.0000

for i in range(1, len(stocks_df)):
  df_portfolio['portfolio daily % return'][i] = ((df_portfolio['sum of all $ values (portfolio daily worth in $)'][i] - df_portfolio['sum of all $ values (portfolio daily worth in $)'][i-1]) / df_portfolio['sum of all $ values (portfolio daily worth in $)'][i-1]) * 100

df_portfolio
# Out:
#             Date  ...  portfolio daily % return
# 0     2012-01-12  ...                  0.000000
# 1     2012-01-13  ...                 -1.522076
# 2     2012-01-17  ...                  1.613507
# 3     2012-01-18  ...                  1.322705
# 4     2012-01-19  ...                  0.681427
# ...          ...  ...                       ...
# 2154  2020-08-05  ...                  0.879605
# 2155  2020-08-06  ...                  0.882669
# 2156  2020-08-07  ...                 -1.827981
# 2157  2020-08-10  ...                 -0.653686
# 2158  2020-08-11  ...                 -2.292973
#
# [2159 rows x 12 columns]

# %% [markdown]
# **MINI CHALLENGE #3:**
# - **Try at least 3 another random weights allocation and rerun the code.**
# - **Compare the final portfolio value on Aug 11th, 2020 to its initial value ($1M) on January 12th, 2012. Do you notice a big difference? Comment on your answer.**

# %%
np.random.seed(102)

# %%
weights = np.array(np.random.random(9))
weights
# Out:
# array([0.59768158, 0.6759869 , 0.29928174, 0.73074027, 0.57873939,
#        0.80901767, 0.1672485 , 0.31214497, 0.35793155])

# %%
weights = weights / np.sum(weights)
print(weights)
# Out:
# [0.1319743  0.14926493 0.06608452 0.16135504 0.12779167 0.1786395
#  0.03693021 0.06892485 0.079035  ]

# %%
df_portfolio = normalization(stocks_df)
df_portfolio
# Out:
#             Date      AAPL        BA  ...       TSLA      GOOG     sp500
# 0     2012-01-12  1.000000  1.000000  ...   1.000000  1.000000  1.000000
# 1     2012-01-13  0.996251  0.987949  ...   0.806726  0.992615  0.995052
# 2     2012-01-17  1.007855  0.996424  ...   0.941593  0.998317  0.998587
# 3     2012-01-18  1.018320  0.994040  ...   0.949027  1.005193  1.009680
# 4     2012-01-19  1.015093  1.000662  ...   0.947257  1.015771  1.014666
# ...          ...       ...       ...  ...        ...       ...       ...
# 2154  2020-08-05  7.313297  2.308039  ...  52.567080  4.698347  2.568715
# 2155  2020-08-06  7.568452  2.280493  ...  52.728494  4.782805  2.585226
# 2156  2020-08-07  7.383066  2.251622  ...  51.423361  4.764919  2.586862
# 2157  2020-08-10  7.490377  2.375977  ...  50.214865  4.770052  2.593956
# 2158  2020-08-11  7.267614  2.385512  ...  48.650974  4.719740  2.573284
#
# [2159 rows x 10 columns]

# %%
for counter, stock in enumerate(df_portfolio.columns[1:]):
  df_portfolio[stock] = df_portfolio[stock] * weights[counter]
  df_portfolio[stock] = df_portfolio[stock] * 1000000

df_portfolio
# Out:
#             Date           AAPL  ...           GOOG          sp500
# 0     2012-01-12  131974.298475  ...   68924.849433   79035.002797
# 1     2012-01-13  131479.466407  ...   68415.828155   78643.943704
# 2     2012-01-17  133010.954907  ...   68808.815616   78923.362057
# 3     2012-01-18  134392.116287  ...   69282.809301   79800.037160
# 4     2012-01-19  133966.177755  ...   70011.860266   80194.142166
# ...          ...            ...  ...            ...            ...
# 2154  2020-08-05  965167.194228  ...  323832.828321  203018.381194
# 2155  2020-08-06  998841.137728  ...  329654.130290  204323.321506
# 2156  2020-08-07  974374.948454  ...  328421.309088  204452.664195
# 2157  2020-08-10  988537.293379  ...  328775.111196  205013.318067
# 2158  2020-08-11  959138.324758  ...  325307.374280  203379.539799
#
# [2159 rows x 10 columns]

# %%
# Let's create an additional column that contains the sum of all $ values in the portfolio
df_portfolio['portfolio daily worth in $'] = df_portfolio[df_portfolio != 'Date'].sum(axis=1)
df_portfolio
# Out:
#             Date           AAPL  ...          sp500  portfolio daily worth in $
# 0     2012-01-12  131974.298475  ...   79035.002797                1.000000e+06
# 1     2012-01-13  131479.466407  ...   78643.943704                9.929187e+05
# 2     2012-01-17  133010.954907  ...   78923.362057                1.003618e+06
# 3     2012-01-18  134392.116287  ...   79800.037160                1.019539e+06
# 4     2012-01-19  133966.177755  ...   80194.142166                1.025383e+06
# ...          ...            ...  ...            ...                         ...
# 2154  2020-08-05  965167.194228  ...  203018.381194                6.517930e+06
# 2155  2020-08-06  998841.137728  ...  204323.321506                6.598872e+06
# 2156  2020-08-07  974374.948454  ...  204452.664195                6.485828e+06
# 2157  2020-08-10  988537.293379  ...  205013.318067                6.498191e+06
# 2158  2020-08-11  959138.324758  ...  203379.539799                6.355985e+06
#
# [2159 rows x 11 columns]

# %%
# Let's calculate the portfolio daily return 
# Define a new column in the dataframe and set it to zeros

df_portfolio['portfolio daily % return'] = 0.0000

for i in range(1, len(stocks_df)):
  df_portfolio['portfolio daily % return'][i] = ((df_portfolio['portfolio daily worth in $'][i] - df_portfolio['portfolio daily worth in $'][i-1]) / df_portfolio['portfolio daily worth in $'][i-1]) * 100

df_portfolio
# Out:
#             Date  ...  portfolio daily % return
# 0     2012-01-12  ...                  0.000000
# 1     2012-01-13  ...                 -0.708127
# 2     2012-01-17  ...                  1.077528
# 3     2012-01-18  ...                  1.586361
# 4     2012-01-19  ...                  0.573182
# ...          ...  ...                       ...
# 2154  2020-08-05  ...                  1.080106
# 2155  2020-08-06  ...                  1.241836
# 2156  2020-08-07  ...                 -1.713083
# 2157  2020-08-10  ...                  0.190619
# 2158  2020-08-11  ...                 -2.188406
#
# [2159 rows x 12 columns]

# %% [markdown]
# # TASK #5: PORTFOLIO ALLOCATION - DAILY RETURN/WORTH CALCULATION (FUNCTION)

# %%
# Lets assume we have $1,000,000 to be invested and we will allocate this fund based on the weights of the stocks
# We will create a function that takes in the stock prices along with the weights and return:
# (1) Daily value of each individual securuty in $ over the specified time period
# (2) Overall daily worth of the entire portfolio 
# (3) Daily return 

def portfolio_allocation(df, weights):
  df_portfolio = df.copy()
  df_portfolio = normalization(df_portfolio)

  for counter, stock in enumerate(df_portfolio.columns[1:]):
    df_portfolio[stock] = df_portfolio[stock] * weights[counter]
    df_portfolio[stock] = df_portfolio[stock] * 1000000

  df_portfolio['portfolio daily worth in $'] = df_portfolio[df_portfolio != 'Date'].sum(axis=1)

  df_portfolio['portfolio daily % return'] = 0.0000

  for i in range(1, len(df_portfolio)):
    df_portfolio['portfolio daily % return'][i] = ((df_portfolio['portfolio daily worth in $'][i] - df_portfolio['portfolio daily worth in $'][i-1]) / df_portfolio['portfolio daily worth in $'][i-1]) * 100

  df_portfolio['portfolio daily % return'][0] = 0

  return df_portfolio

# %% [markdown]
# **MINI CHALLENGE #4:**
# - **Call the function and ensure that the results make sense**

# %%
# np.random.seed(102)

# weights = np.array(np.random.random(9))
# weights

df_portfolio_2 = portfolio_allocation(stocks_df, weights)
df_portfolio_2
# Out:
#             Date  ...  portfolio daily % return
# 0     2012-01-12  ...                  0.000000
# 1     2012-01-13  ...                 -0.708127
# 2     2012-01-17  ...                  1.077528
# 3     2012-01-18  ...                  1.586361
# 4     2012-01-19  ...                  0.573182
# ...          ...  ...                       ...
# 2154  2020-08-05  ...                  1.080106
# 2155  2020-08-06  ...                  1.241836
# 2156  2020-08-07  ...                 -1.713083
# 2157  2020-08-10  ...                  0.190619
# 2158  2020-08-11  ...                 -2.188406
#
# [2159 rows x 12 columns]

# %%
stocks_df = pd.read_csv("stock.csv", index_col=["Date"])
stocks_df
# Out:
#                   AAPL          BA  ...         GOOG        sp500
# Date                                ...
# 2012-01-12   60.198570   75.510002  ...   313.644379  1295.500000
# 2012-01-13   59.972858   74.599998  ...   311.328064  1289.089966
# 2012-01-17   60.671429   75.239998  ...   313.116364  1293.670044
# 2012-01-18   61.301430   75.059998  ...   315.273285  1308.040039
# 2012-01-19   61.107143   75.559998  ...   318.590851  1314.500000
# ...                ...         ...  ...          ...          ...
# 2020-08-05  440.250000  174.279999  ...  1473.609985  3327.770020
# 2020-08-06  455.609985  172.199997  ...  1500.099976  3349.159912
# 2020-08-07  444.450012  170.020004  ...  1494.489990  3351.280029
# 2020-08-10  450.910004  179.410004  ...  1496.099976  3360.469971
# 2020-08-11  437.500000  180.130005  ...  1480.319946  3333.689941
#
# [2159 rows x 9 columns]

# %%
def portfolio_allocation_3(df, weights):
    df_portfolio = df.copy()
    df_portfolio = normalization(df_portfolio)
    df_portfolio = df_portfolio.mul(weights).mul(10000000)
    df_portfolio["Portfolio_daily_worth_value"] = df_portfolio.sum(axis=1)
    df_portfolio["Portfolio_Daily_return_%"] = df_portfolio["Portfolio_daily_worth_value"].pct_change().mul(100).fillna(0)

# %%
df_portfolio_3 = portfolio_allocation_3(stocks_df, weights)
df_portfolio_3

# %% [markdown]
# # TASK #6: PERFORM PORTFOLIO DATA VISUALIZATION

# %%
# Plot the portfolio daily return
fig = px.line(x=df_portfolio['Date'], y=df_portfolio['portfolio daily % return'], title='Portfolio Daily % Return')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1389f859-c2da-4ea2-8a90-68927ca2d7fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1389f859-c2da-4ea2-8a90-68927ca2d7fe")) {
#                     Plotly.newPlot(
#                         '1389f859-c2da-4ea2-8a90-68927ca2d7fe',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{x}<br>y=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": ["2012-01-12", "2012-01-13", "2012-01-17", "2012-01-18", "2012-01-19", "2012-01-20", "2012-01-23", "2012-01-24", "2012-01-25", "2012-01-26", "2012-01-27", "2012-01-30", "2012-01-31", "2012-02-01", "2012-02-02", "2012-02-03", "2012-02-06", "2012-02-07", "2012-02-08", "2012-02-09", "2012-02-10", "2012-02-13", "2012-02-14", "2012-02-15", "2012-02-16", "2012-02-17", "2012-02-21", "2012-02-22", "2012-02-23", "2012-02-24", "2012-02-27", "2012-02-28", "2012-02-29", "2012-03-01", "2012-03-02", "2012-03-05", "2012-03-06", "2012-03-07", "2012-03-08", "2012-03-09", "2012-03-12", "2012-03-13", "2012-03-14", "2012-03-15", "2012-03-16", "2012-03-19", "2012-03-20", "2012-03-21", "2012-03-22", "2012-03-23", "2012-03-26", "2012-03-27", "2012-03-28", "2012-03-29", "2012-03-30", "2012-04-02", "2012-04-03", "2012-04-04", "2012-04-05", "2012-04-09", "2012-04-10", "2012-04-11", "2012-04-12", "2012-04-13", "2012-04-16", "2012-04-17", "2012-04-18", "2012-04-19", "2012-04-20", "2012-04-23", "2012-04-24", "2012-04-25", "2012-04-26", "2012-04-27", "2012-04-30", "2012-05-01", "2012-05-02", "2012-05-03", "2012-05-04", "2012-05-07", "2012-05-08", "2012-05-09", "2012-05-10", "2012-05-11", "2012-05-14", "2012-05-15", "2012-05-16", "2012-05-17", "2012-05-18", "2012-05-21", "2012-05-22", "2012-05-23", "2012-05-24", "2012-05-25", "2012-05-29", "2012-05-30", "2012-05-31", "2012-06-01", "2012-06-04", "2012-06-05", "2012-06-06", "2012-06-07", "2012-06-08", "2012-06-11", "2012-06-12", "2012-06-13", "2012-06-14", "2012-06-15", "2012-06-18", "2012-06-19", "2012-06-20", "2012-06-21", "2012-06-22", "2012-06-25", "2012-06-26", "2012-06-27", "2012-06-28", "2012-06-29", "2012-07-02", "2012-07-03", "2012-07-05", "2012-07-06", "2012-07-09", "2012-07-10", "2012-07-11", "2012-07-12", "2012-07-13", "2012-07-16", "2012-07-17", "2012-07-18", "2012-07-19", "2012-07-20", "2012-07-23", "2012-07-24", "2012-07-25", "2012-07-26", "2012-07-27", "2012-07-30", "2012-07-31", "2012-08-01", "2012-08-02", "2012-08-03", "2012-08-06", "2012-08-07", "2012-08-08", "2012-08-09", "2012-08-10", "2012-08-13", "2012-08-14", "2012-08-15", "2012-08-16", "2012-08-17", "2012-08-20", "2012-08-21", "2012-08-22", "2012-08-23", "2012-08-24", "2012-08-27", "2012-08-28", "2012-08-29", "2012-08-30", "2012-08-31", "2012-09-04", "2012-09-05", "2012-09-06", "2012-09-07", "2012-09-10", "2012-09-11", "2012-09-12", "2012-09-13", "2012-09-14", "2012-09-17", "2012-09-18", "2012-09-19", "2012-09-20", "2012-09-21", "2012-09-24", "2012-09-25", "2012-09-26", "2012-09-27", "2012-09-28", "2012-10-01", "2012-10-02", "2012-10-03", "2012-10-04", "2012-10-05", "2012-10-08", "2012-10-09", "2012-10-10", "2012-10-11", "2012-10-12", "2012-10-15", "2012-10-16", "2012-10-17", "2012-10-18", "2012-10-19", "2012-10-22", "2012-10-23", "2012-10-24", "2012-10-25", "2012-10-26", "2012-10-31", "2012-11-01", "2012-11-02", "2012-11-05", "2012-11-06", "2012-11-07", "2012-11-08", "2012-11-09", "2012-11-12", "2012-11-13", "2012-11-14", "2012-11-15", "2012-11-16", "2012-11-19", "2012-11-20", "2012-11-21", "2012-11-23", "2012-11-26", "2012-11-27", "2012-11-28", "2012-11-29", "2012-11-30", "2012-12-03", "2012-12-04", "2012-12-05", "2012-12-06", "2012-12-07", "2012-12-10", "2012-12-11", "2012-12-12", "2012-12-13", "2012-12-14", "2012-12-17", "2012-12-18", "2012-12-19", "2012-12-20", "2012-12-21", "2012-12-24", "2012-12-26", "2012-12-27", "2012-12-28", "2012-12-31", "2013-01-02", "2013-01-03", "2013-01-04", "2013-01-07", "2013-01-08", "2013-01-09", "2013-01-10", "2013-01-11", "2013-01-14", "2013-01-15", "2013-01-16", "2013-01-17", "2013-01-18", "2013-01-22", "2013-01-23", "2013-01-24", "2013-01-25", "2013-01-28", "2013-01-29", "2013-01-30", "2013-01-31", "2013-02-01", "2013-02-04", "2013-02-05", "2013-02-06", "2013-02- ...

# %%
# Plot all stocks (normalized)

interactive_plot(df_portfolio_2.drop(['portfolio daily worth in $', 'portfolio daily % return'], axis=1), 'Portfolio Individual Stocks worth in $ overtime')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9218577a-d4b0-4456-b5ee-8c318404e5a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9218577a-d4b0-4456-b5ee-8c318404e5a2")) {
#                     Plotly.newPlot(
#                         '9218577a-d4b0-4456-b5ee-8c318404e5a2',
#                         [{"name": "AAPL", "type": "scatter", "x": ["2012-01-12", "2012-01-13", "2012-01-17", "2012-01-18", "2012-01-19", "2012-01-20", "2012-01-23", "2012-01-24", "2012-01-25", "2012-01-26", "2012-01-27", "2012-01-30", "2012-01-31", "2012-02-01", "2012-02-02", "2012-02-03", "2012-02-06", "2012-02-07", "2012-02-08", "2012-02-09", "2012-02-10", "2012-02-13", "2012-02-14", "2012-02-15", "2012-02-16", "2012-02-17", "2012-02-21", "2012-02-22", "2012-02-23", "2012-02-24", "2012-02-27", "2012-02-28", "2012-02-29", "2012-03-01", "2012-03-02", "2012-03-05", "2012-03-06", "2012-03-07", "2012-03-08", "2012-03-09", "2012-03-12", "2012-03-13", "2012-03-14", "2012-03-15", "2012-03-16", "2012-03-19", "2012-03-20", "2012-03-21", "2012-03-22", "2012-03-23", "2012-03-26", "2012-03-27", "2012-03-28", "2012-03-29", "2012-03-30", "2012-04-02", "2012-04-03", "2012-04-04", "2012-04-05", "2012-04-09", "2012-04-10", "2012-04-11", "2012-04-12", "2012-04-13", "2012-04-16", "2012-04-17", "2012-04-18", "2012-04-19", "2012-04-20", "2012-04-23", "2012-04-24", "2012-04-25", "2012-04-26", "2012-04-27", "2012-04-30", "2012-05-01", "2012-05-02", "2012-05-03", "2012-05-04", "2012-05-07", "2012-05-08", "2012-05-09", "2012-05-10", "2012-05-11", "2012-05-14", "2012-05-15", "2012-05-16", "2012-05-17", "2012-05-18", "2012-05-21", "2012-05-22", "2012-05-23", "2012-05-24", "2012-05-25", "2012-05-29", "2012-05-30", "2012-05-31", "2012-06-01", "2012-06-04", "2012-06-05", "2012-06-06", "2012-06-07", "2012-06-08", "2012-06-11", "2012-06-12", "2012-06-13", "2012-06-14", "2012-06-15", "2012-06-18", "2012-06-19", "2012-06-20", "2012-06-21", "2012-06-22", "2012-06-25", "2012-06-26", "2012-06-27", "2012-06-28", "2012-06-29", "2012-07-02", "2012-07-03", "2012-07-05", "2012-07-06", "2012-07-09", "2012-07-10", "2012-07-11", "2012-07-12", "2012-07-13", "2012-07-16", "2012-07-17", "2012-07-18", "2012-07-19", "2012-07-20", "2012-07-23", "2012-07-24", "2012-07-25", "2012-07-26", "2012-07-27", "2012-07-30", "2012-07-31", "2012-08-01", "2012-08-02", "2012-08-03", "2012-08-06", "2012-08-07", "2012-08-08", "2012-08-09", "2012-08-10", "2012-08-13", "2012-08-14", "2012-08-15", "2012-08-16", "2012-08-17", "2012-08-20", "2012-08-21", "2012-08-22", "2012-08-23", "2012-08-24", "2012-08-27", "2012-08-28", "2012-08-29", "2012-08-30", "2012-08-31", "2012-09-04", "2012-09-05", "2012-09-06", "2012-09-07", "2012-09-10", "2012-09-11", "2012-09-12", "2012-09-13", "2012-09-14", "2012-09-17", "2012-09-18", "2012-09-19", "2012-09-20", "2012-09-21", "2012-09-24", "2012-09-25", "2012-09-26", "2012-09-27", "2012-09-28", "2012-10-01", "2012-10-02", "2012-10-03", "2012-10-04", "2012-10-05", "2012-10-08", "2012-10-09", "2012-10-10", "2012-10-11", "2012-10-12", "2012-10-15", "2012-10-16", "2012-10-17", "2012-10-18", "2012-10-19", "2012-10-22", "2012-10-23", "2012-10-24", "2012-10-25", "2012-10-26", "2012-10-31", "2012-11-01", "2012-11-02", "2012-11-05", "2012-11-06", "2012-11-07", "2012-11-08", "2012-11-09", "2012-11-12", "2012-11-13", "2012-11-14", "2012-11-15", "2012-11-16", "2012-11-19", "2012-11-20", "2012-11-21", "2012-11-23", "2012-11-26", "2012-11-27", "2012-11-28", "2012-11-29", "2012-11-30", "2012-12-03", "2012-12-04", "2012-12-05", "2012-12-06", "2012-12-07", "2012-12-10", "2012-12-11", "2012-12-12", "2012-12-13", "2012-12-14", "2012-12-17", "2012-12-18", "2012-12-19", "2012-12-20", "2012-12-21", "2012-12-24", "2012-12-26", "2012-12-27", "2012-12-28", "2012-12-31", "2013-01-02", "2013-01-03", "2013-01-04", "2013-01-07", "2013-01-08", "2013-01-09", "2013-01-10", "2013-01-11", "2013-01-14", "2013-01-15", "2013-01-16", "2013-01-17", "2013-01-18", "2013-01-22", "2013-01-23", "2013-01-24", "2013-01-25", "2013-01-28", "2013-01-29", "2013-01-30", "2013-01-31", "2013-02-01", "2013-02-04", "2013-02-05", "2013-02-06", "2013-02-07", "2013-02-08", "2013-02-11", "2013-02-12", "2013-02-13", "2013-02-14", "2013-02-15", "2013-02-19", "2013-02-20", "2013-02-21", "2013-02-22", "2013-02-25", "2013-02-26", ...

# %%
# Print out a histogram of daily returns
fig = px.histogram(df_portfolio_2, x='portfolio daily % return')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="df469196-66d2-47cd-acc9-14eb891c3f8c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("df469196-66d2-47cd-acc9-14eb891c3f8c")) {
#                     Plotly.newPlot(
#                         'df469196-66d2-47cd-acc9-14eb891c3f8c',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "portfolio daily % return=%{x}<br>count=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [0.0, -0.70812668967169, 1.0775284837626142, 1.5863605149628728, 0.5731822309592464, -0.4881525826229696, 0.6619335917302549, -0.004639855348297165, 0.9030109289090198, -0.018485214174998862, 0.309835533881295, 0.04103091617097294, 0.1237431652958706, 0.1845666499253409, 0.42585098986535924, 1.9330584343583257, -0.6467324515933075, 0.12266474787868155, 0.8040320115584303, 0.895834343163965, -0.3153396445791293, 0.8171219242729212, 0.34992191916931553, -0.9145038955638073, 0.3853792004941752, 0.2148319278621178, -0.050068808771466085, -0.7062552455484035, 0.9939047553804558, -0.15593701525545922, -0.5301994475129551, 1.284086211712815, -0.6116989592190125, 0.5908290267060922, -0.08740925736374928, -0.8466222593328946, -1.4101257942850005, 0.9337364057947889, 1.472236850049956, -0.130095269977369, 0.2717241427611065, 2.261316756221738, 0.21879554617895333, 0.9730985319532413, -0.2658407499922905, 0.5937153266935166, 0.18229585417347674, -0.026304239613207273, -0.48049812015963494, 0.11955783496651476, 2.2133640881656746, 0.19367868656953663, -0.8209760308806291, -0.31732618017727676, -0.6439270980230954, 0.6427455394496908, 0.6366153963410537, -1.850408094860213, 0.06449510158979123, -0.754230381868744, -1.9447738889933088, 1.1540456029117558, 1.3048631000253221, -1.267051888164843, -1.509322277522121, 2.023120997269832, -0.6762062037360015, -0.7912478663551974, -0.6931891760354169, -1.0904382945956415, 0.20097696672801046, 3.4029681018571756, 1.0143829239207753, 2.0341561049238406, -0.768058344627682, -0.021197322639331516, 0.4471371789380032, -1.2041988865869897, -2.0624687913857307, -0.054189980975777104, -1.0718185505215099, -0.6343009489045964, 0.6651271159523517, -0.17192819141658974, -1.7399036096396518, -0.42511813275087185, -0.2444570871299515, -2.3478344993874427, -1.0273865983068486, 2.9979465580941165, -0.5439743408173705, 0.6358322110846397, -0.32095239455554053, -0.9054883086066554, 1.5550243809446513, -1.1862899679081247, -0.15070847307613833, -2.6889145988817194, 0.6941323119790088, 0.5310806198819492, 2.2135872296428607, 0.14482150057883755, 0.8175767289192081, -1.3595630531975227, 1.2345097997062098, -0.8567497877339779, 0.41645126995012705, 0.5620587943071815, 0.9628319020304835, 0.8385247736388342, 0.14525575975042648, -2.0451831080735907, 0.7350179477532951, -1.6709724523576452, 0.3176244185007087, 0.6041587657813404, -0.5425056531308605, 2.643083997420428, 0.019265410394313173, 0.6210873650630627, 0.00697595296112639, -1.17914011989817, -0.19953419505841663, -1.293263452168959, -0.8996580551109541, -1.0813532567081037, 1.5379601635889328, -0.17708801306327343, 0.1824531653563332, 0.7288173637025805, 1.8645724395552843, -1.2229790882454592, -0.6403047334187805, -1.342351301521271, -0.9409937344235517, 0.9405902232512926, 2.7983412034058155, -0.07167300950894194, 0.15813409702982403, -0.8101741118676142, -0.9119631038898975, 1.774765541449371, 0.4689327353040198, 1.5674542057921483, -0.6488852622868371, -0.34323802601013564, 0.1936041464482566, 0.7992976955005414, -0.1587704919857016, 0.3920755173277177, 1.1616161146429662, 0.5632600767710797, 0.30486207875982657, -0.8864345073107521, 0.5717282353832897, -1.0661769997280948, 0.639377707060026, -0.3938454182433504, 0.06792497401979689, 0.2737434187080534, -1.0961150372674997, 0.512091016749313, -0.05191042196439511, -0.00986895298341458, 2.1736563943232348, 1.2308131323608615, -0.8290201576717133, -0.04833759637412932, 0.5184931637093769, 1.8115916187476335, 0.41415804594923017, -0.09642212751109022, -0.07191757581931783, 0.24246270730778374, -0.5654644318831512, -0.26046791600769903, -0.27491308231371764, -1.433645067516029, -0.2559950016495532, 1.58 ...

# %% [markdown]
# **MINI CHALLENGE #5:**
# - **Plot the portfolio overall daily worth vs. time.**
# - **Rerun the code with various weights and visualize the final value.**

# %%
fig = px.line(x=df_portfolio_2.Date, y=df_portfolio_2['portfolio daily worth in $'], title='The portfolio overall daily worth vs. time')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ff2d8a07-86a2-4d83-90c8-e03a4b01f0cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ff2d8a07-86a2-4d83-90c8-e03a4b01f0cb")) {
#                     Plotly.newPlot(
#                         'ff2d8a07-86a2-4d83-90c8-e03a4b01f0cb',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{x}<br>y=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": ["2012-01-12", "2012-01-13", "2012-01-17", "2012-01-18", "2012-01-19", "2012-01-20", "2012-01-23", "2012-01-24", "2012-01-25", "2012-01-26", "2012-01-27", "2012-01-30", "2012-01-31", "2012-02-01", "2012-02-02", "2012-02-03", "2012-02-06", "2012-02-07", "2012-02-08", "2012-02-09", "2012-02-10", "2012-02-13", "2012-02-14", "2012-02-15", "2012-02-16", "2012-02-17", "2012-02-21", "2012-02-22", "2012-02-23", "2012-02-24", "2012-02-27", "2012-02-28", "2012-02-29", "2012-03-01", "2012-03-02", "2012-03-05", "2012-03-06", "2012-03-07", "2012-03-08", "2012-03-09", "2012-03-12", "2012-03-13", "2012-03-14", "2012-03-15", "2012-03-16", "2012-03-19", "2012-03-20", "2012-03-21", "2012-03-22", "2012-03-23", "2012-03-26", "2012-03-27", "2012-03-28", "2012-03-29", "2012-03-30", "2012-04-02", "2012-04-03", "2012-04-04", "2012-04-05", "2012-04-09", "2012-04-10", "2012-04-11", "2012-04-12", "2012-04-13", "2012-04-16", "2012-04-17", "2012-04-18", "2012-04-19", "2012-04-20", "2012-04-23", "2012-04-24", "2012-04-25", "2012-04-26", "2012-04-27", "2012-04-30", "2012-05-01", "2012-05-02", "2012-05-03", "2012-05-04", "2012-05-07", "2012-05-08", "2012-05-09", "2012-05-10", "2012-05-11", "2012-05-14", "2012-05-15", "2012-05-16", "2012-05-17", "2012-05-18", "2012-05-21", "2012-05-22", "2012-05-23", "2012-05-24", "2012-05-25", "2012-05-29", "2012-05-30", "2012-05-31", "2012-06-01", "2012-06-04", "2012-06-05", "2012-06-06", "2012-06-07", "2012-06-08", "2012-06-11", "2012-06-12", "2012-06-13", "2012-06-14", "2012-06-15", "2012-06-18", "2012-06-19", "2012-06-20", "2012-06-21", "2012-06-22", "2012-06-25", "2012-06-26", "2012-06-27", "2012-06-28", "2012-06-29", "2012-07-02", "2012-07-03", "2012-07-05", "2012-07-06", "2012-07-09", "2012-07-10", "2012-07-11", "2012-07-12", "2012-07-13", "2012-07-16", "2012-07-17", "2012-07-18", "2012-07-19", "2012-07-20", "2012-07-23", "2012-07-24", "2012-07-25", "2012-07-26", "2012-07-27", "2012-07-30", "2012-07-31", "2012-08-01", "2012-08-02", "2012-08-03", "2012-08-06", "2012-08-07", "2012-08-08", "2012-08-09", "2012-08-10", "2012-08-13", "2012-08-14", "2012-08-15", "2012-08-16", "2012-08-17", "2012-08-20", "2012-08-21", "2012-08-22", "2012-08-23", "2012-08-24", "2012-08-27", "2012-08-28", "2012-08-29", "2012-08-30", "2012-08-31", "2012-09-04", "2012-09-05", "2012-09-06", "2012-09-07", "2012-09-10", "2012-09-11", "2012-09-12", "2012-09-13", "2012-09-14", "2012-09-17", "2012-09-18", "2012-09-19", "2012-09-20", "2012-09-21", "2012-09-24", "2012-09-25", "2012-09-26", "2012-09-27", "2012-09-28", "2012-10-01", "2012-10-02", "2012-10-03", "2012-10-04", "2012-10-05", "2012-10-08", "2012-10-09", "2012-10-10", "2012-10-11", "2012-10-12", "2012-10-15", "2012-10-16", "2012-10-17", "2012-10-18", "2012-10-19", "2012-10-22", "2012-10-23", "2012-10-24", "2012-10-25", "2012-10-26", "2012-10-31", "2012-11-01", "2012-11-02", "2012-11-05", "2012-11-06", "2012-11-07", "2012-11-08", "2012-11-09", "2012-11-12", "2012-11-13", "2012-11-14", "2012-11-15", "2012-11-16", "2012-11-19", "2012-11-20", "2012-11-21", "2012-11-23", "2012-11-26", "2012-11-27", "2012-11-28", "2012-11-29", "2012-11-30", "2012-12-03", "2012-12-04", "2012-12-05", "2012-12-06", "2012-12-07", "2012-12-10", "2012-12-11", "2012-12-12", "2012-12-13", "2012-12-14", "2012-12-17", "2012-12-18", "2012-12-19", "2012-12-20", "2012-12-21", "2012-12-24", "2012-12-26", "2012-12-27", "2012-12-28", "2012-12-31", "2013-01-02", "2013-01-03", "2013-01-04", "2013-01-07", "2013-01-08", "2013-01-09", "2013-01-10", "2013-01-11", "2013-01-14", "2013-01-15", "2013-01-16", "2013-01-17", "2013-01-18", "2013-01-22", "2013-01-23", "2013-01-24", "2013-01-25", "2013-01-28", "2013-01-29", "2013-01-30", "2013-01-31", "2013-02-01", "2013-02-04", "2013-02-05", "2013-02-06", "2013-02- ...

# %%
interactive_plot(df_portfolio_2.drop(['AAPL', 'BA', 'T', 'MGM', 'AMZN', 'IBM', 'TSLA', 'GOOG', 'sp500', 'portfolio daily % return'], axis=1), 'The portfolio overall daily worth vs. time')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c97085ca-9084-4954-9b61-640da8d08e54" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c97085ca-9084-4954-9b61-640da8d08e54")) {
#                     Plotly.newPlot(
#                         'c97085ca-9084-4954-9b61-640da8d08e54',
#                         [{"name": "portfolio daily worth in $", "type": "scatter", "x": ["2012-01-12", "2012-01-13", "2012-01-17", "2012-01-18", "2012-01-19", "2012-01-20", "2012-01-23", "2012-01-24", "2012-01-25", "2012-01-26", "2012-01-27", "2012-01-30", "2012-01-31", "2012-02-01", "2012-02-02", "2012-02-03", "2012-02-06", "2012-02-07", "2012-02-08", "2012-02-09", "2012-02-10", "2012-02-13", "2012-02-14", "2012-02-15", "2012-02-16", "2012-02-17", "2012-02-21", "2012-02-22", "2012-02-23", "2012-02-24", "2012-02-27", "2012-02-28", "2012-02-29", "2012-03-01", "2012-03-02", "2012-03-05", "2012-03-06", "2012-03-07", "2012-03-08", "2012-03-09", "2012-03-12", "2012-03-13", "2012-03-14", "2012-03-15", "2012-03-16", "2012-03-19", "2012-03-20", "2012-03-21", "2012-03-22", "2012-03-23", "2012-03-26", "2012-03-27", "2012-03-28", "2012-03-29", "2012-03-30", "2012-04-02", "2012-04-03", "2012-04-04", "2012-04-05", "2012-04-09", "2012-04-10", "2012-04-11", "2012-04-12", "2012-04-13", "2012-04-16", "2012-04-17", "2012-04-18", "2012-04-19", "2012-04-20", "2012-04-23", "2012-04-24", "2012-04-25", "2012-04-26", "2012-04-27", "2012-04-30", "2012-05-01", "2012-05-02", "2012-05-03", "2012-05-04", "2012-05-07", "2012-05-08", "2012-05-09", "2012-05-10", "2012-05-11", "2012-05-14", "2012-05-15", "2012-05-16", "2012-05-17", "2012-05-18", "2012-05-21", "2012-05-22", "2012-05-23", "2012-05-24", "2012-05-25", "2012-05-29", "2012-05-30", "2012-05-31", "2012-06-01", "2012-06-04", "2012-06-05", "2012-06-06", "2012-06-07", "2012-06-08", "2012-06-11", "2012-06-12", "2012-06-13", "2012-06-14", "2012-06-15", "2012-06-18", "2012-06-19", "2012-06-20", "2012-06-21", "2012-06-22", "2012-06-25", "2012-06-26", "2012-06-27", "2012-06-28", "2012-06-29", "2012-07-02", "2012-07-03", "2012-07-05", "2012-07-06", "2012-07-09", "2012-07-10", "2012-07-11", "2012-07-12", "2012-07-13", "2012-07-16", "2012-07-17", "2012-07-18", "2012-07-19", "2012-07-20", "2012-07-23", "2012-07-24", "2012-07-25", "2012-07-26", "2012-07-27", "2012-07-30", "2012-07-31", "2012-08-01", "2012-08-02", "2012-08-03", "2012-08-06", "2012-08-07", "2012-08-08", "2012-08-09", "2012-08-10", "2012-08-13", "2012-08-14", "2012-08-15", "2012-08-16", "2012-08-17", "2012-08-20", "2012-08-21", "2012-08-22", "2012-08-23", "2012-08-24", "2012-08-27", "2012-08-28", "2012-08-29", "2012-08-30", "2012-08-31", "2012-09-04", "2012-09-05", "2012-09-06", "2012-09-07", "2012-09-10", "2012-09-11", "2012-09-12", "2012-09-13", "2012-09-14", "2012-09-17", "2012-09-18", "2012-09-19", "2012-09-20", "2012-09-21", "2012-09-24", "2012-09-25", "2012-09-26", "2012-09-27", "2012-09-28", "2012-10-01", "2012-10-02", "2012-10-03", "2012-10-04", "2012-10-05", "2012-10-08", "2012-10-09", "2012-10-10", "2012-10-11", "2012-10-12", "2012-10-15", "2012-10-16", "2012-10-17", "2012-10-18", "2012-10-19", "2012-10-22", "2012-10-23", "2012-10-24", "2012-10-25", "2012-10-26", "2012-10-31", "2012-11-01", "2012-11-02", "2012-11-05", "2012-11-06", "2012-11-07", "2012-11-08", "2012-11-09", "2012-11-12", "2012-11-13", "2012-11-14", "2012-11-15", "2012-11-16", "2012-11-19", "2012-11-20", "2012-11-21", "2012-11-23", "2012-11-26", "2012-11-27", "2012-11-28", "2012-11-29", "2012-11-30", "2012-12-03", "2012-12-04", "2012-12-05", "2012-12-06", "2012-12-07", "2012-12-10", "2012-12-11", "2012-12-12", "2012-12-13", "2012-12-14", "2012-12-17", "2012-12-18", "2012-12-19", "2012-12-20", "2012-12-21", "2012-12-24", "2012-12-26", "2012-12-27", "2012-12-28", "2012-12-31", "2013-01-02", "2013-01-03", "2013-01-04", "2013-01-07", "2013-01-08", "2013-01-09", "2013-01-10", "2013-01-11", "2013-01-14", "2013-01-15", "2013-01-16", "2013-01-17", "2013-01-18", "2013-01-22", "2013-01-23", "2013-01-24", "2013-01-25", "2013-01-28", "2013-01-29", "2013-01-30", "2013-01-31", "2013-02-01", "2013-02-04", "2013-02-05", "2013-02-06", "2013-02-07", "2013-02-08", "2013-02-11", "2013-02-12", "2013-02-13", "2013-02-14", "2013-02-15", "2013-02-19", "2013-02-20", "2013-02-21", "2013-02-22", "2013 ...

# %% [markdown]
# # TASK #7: UNDERSTAND PORTFOLIO STATISTICAL METRICS (CUMMULATIVE RETURN, AVERAGE DAILY RETURN, AND SHARPE RATIO)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1W_MNP2Qldn3ulrvXivOnjQg3NTf3hNCo)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=12e4Zgxv1FNviJYML88G6cTnlte0bts-4)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1QQLWpIJ8uXopJrV40YFKb5H-SxnmsRaj)

# %% [markdown]
# # TASK #8: CALCULATE PORTFOLIO STATISTICAL METRICS (CUMMULATIVE RETURN, AVERAGE DAILY RETURN, AND SHARPE RATIO)

# %%
df_portfolio
# Out:
#             Date  ...  portfolio daily % return
# 0     2012-01-12  ...                  0.000000
# 1     2012-01-13  ...                 -0.708127
# 2     2012-01-17  ...                  1.077528
# 3     2012-01-18  ...                  1.586361
# 4     2012-01-19  ...                  0.573182
# ...          ...  ...                       ...
# 2154  2020-08-05  ...                  1.080106
# 2155  2020-08-06  ...                  1.241836
# 2156  2020-08-07  ...                 -1.713083
# 2157  2020-08-10  ...                  0.190619
# 2158  2020-08-11  ...                 -2.188406
#
# [2159 rows x 12 columns]

# %%
df_portfolio['portfolio daily worth in $'][-1:]
# Out:
# 2158    6.355985e+06
# Name: portfolio daily worth in $, dtype: float64

# %%
# Cummulative return of the portfolio (Note that we now look for the last net worth of the portfolio compared to it's start value)
cummulative_return = (df_portfolio['portfolio daily worth in $'][-1:] - df_portfolio['portfolio daily worth in $'][0]) / df_portfolio['portfolio daily worth in $'][0]
cummulative_return
# Out:
# 2158    5.355985
# Name: portfolio daily worth in $, dtype: float64

# %%
cummulative_return = cummulative_return * 100
print(f'Cummulative return of the portfolio is {cummulative_return.values[0]} %')
# Out:
# Cummulative return of the portfolio is 535.5984613726431 %

# %%
# Calculate the portfolio standard deviation
print('Standard deviation of the Portfolio is {}'.format(df_portfolio['portfolio daily % return'].std()))
# Out:
# Standard deviation of the Portfolio is 1.387579739105404

# %%
# Calculate the average daily return 
print('Average daily return of the Portfolio is {} %'.format(df_portfolio['portfolio daily % return'].mean()))
# Out:
# Average daily return of the Portfolio is 0.09538013939604038 %

# %%
# Portfolio sharpe ratio
sharpe_ratio = df_portfolio['portfolio daily % return'].mean() / df_portfolio['portfolio daily % return'].std() * np.sqrt(252)
print(f'Sharpe ratio of the portfolio is {sharpe_ratio}')
# Out:
# Sharpe ratio of the portfolio is 1.0911897388439509

# %% [markdown]
# **MINI CHALLENGE #6:**
# - **Try at least 3 different random weights allocation, rerun the code and compare sharpe ratios, daily return and cummulative returns.**

# %% [markdown]
# # **WELL DONE!**

# %% [markdown]
# # **MINI CHALLENGE SOLUTIONS**

# %% [markdown]
# **MINI CHALLENGE #1 SOLUTION:**
# - **Use Plotly express to visualize raw stock data and normalized ones**

# %%
# Function to normalize the prices based on the initial price
def normalize(df):
  x = df.copy()
  for i in x.columns[1:]:
    x[i] = x[i]/x[i][0]
  return x

# %%
# Function to plot interactive plot
def interactive_plot(df, title):
  fig = px.line(title = title)
  for i in df.columns[1:]:
    fig.add_scatter(x = df['Date'], y = df[i], name = i)
  fig.show()

# %%
# Plot interactive chart
# interactive_plot(stocks_df, 'Prices')

# %%
# Plot normalized interactive chart
interactive_plot(normalize(stocks_df), 'Normalized Prices')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-267-c4a950d8970c> in <module>()
#       1 # Plot normalized interactive chart
# ----> 2 interactive_plot(normalize(stocks_df), 'Normalized Prices')
#
# <ipython-input-265-e9b478e024bd> in interactive_plot(df, title)
#       3   fig = px.line(title = title)
#       4   for i in df.columns[1:]:
# ----> 5     fig.add_scatter(x = df['Date'], y = df[i], name = i)
#       6   fig.show()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'Date'

# %% [markdown]
# **MINI CHALLENGE #2 SOLUTION:**
# - **What is the common advice that financial advisors generally recommend to retired seniors when it comes to asset allocations?**

# %%
# The conventional wisdom is to subtract client's age from 100 to calculate the % of portolio that should be allocated to stocks
# For Example: If you're 30 years old, you should have 70% allocated to stocks
# If you are 75 years old, you should invest 25% in stocks (old retired seniors generally recommend a more stable low risk portfolio).

# %% [markdown]
# **MINI CHALLENGE #3 SOLUTION:**
# - **Try at least 3 another random weights allocation and rerun the code.**
# - **Compare the final portfolio value on Aug 11th, 2020 to its initial value ($1M) on January 12th, 2012. Do you notice a big difference? Comment on your answer.**

# %%
# remove the seed value of 101, run the code 3 times, and record the final portolio value on the last day (Aug 11th, 2020)
np.random.seed()

# Portfolio Value Run #1 = $6.383645e+06, weights = [0.01246531 0.23749173 0.18257962 0.03419922 0.08369018 0.23405306
 0.07120053 0.00824087 0.13607948]

# Portfolio Value Run #2 = $9.594104e+06, Weights = [0.13932903 0.04729773 0.15580758 0.03232255 0.0629491  0.15081605
 0.12206726 0.16938746 0.12002324]

# Portfolio Value Run #3 = 1.138105e+07, Weights = [0.17707261 0.06977804 0.02394314 0.1550952  0.11152213 0.12017452
 0.14296447 0.05729485 0.14215505]

# %% [markdown]
# **MINI CHALLENGE #4 SOLUTION:**
# - **Call the function and ensure that the results make sense**

# %%
# Call the function
df_portfolio = portfolio_allocation(stocks_df, weights)
df_portfolio

# %% [markdown]
# **MINI CHALLENGE #5 SOLUTION:**
# - **Plot the portfolio overall daily worth vs. time.**
# - **Rerun the code with various weights and visualize the final value.**

# %%
fig = px.line(x = df_portfolio.Date, y = df_portfolio['portfolio daily worth in $'], title= 'Portfolio Overall Value in $')
fig.show()

# %% [markdown]
# **MINI CHALLENGE #6 SOLUTION:**
# - **Try at least 3 different random weights allocation, rerun the code and compare sharpe ratios, daily return and cummulative returns.**

# %%
# Rerun the code with 3 random values and compare metrics
