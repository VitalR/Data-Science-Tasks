# %% [markdown]
# # Stock Market Analysis of the largest tech companies in 2020

# %% [markdown]
# ## Data Reading

# %%
# Setup
import numpy as np
import pandas as pd
import pandas_datareader.data as web
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %matplotlib inline

# %%
start = datetime.datetime(2020, 1, 1)
end = datetime.datetime(2020, 10, 28)

# %%
amazon = web.DataReader('AMZN', 'yahoo', start, end)

# %%
amazon
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2020-01-02  1898.010010  1864.150024  1875.000000  1898.010010  4029000
# 2020-01-03  1886.199951  1864.500000  1864.500000  1874.969971  3764400
# 2020-01-06  1903.689941  1860.000000  1860.000000  1902.880005  4061800
# 2020-01-07  1913.890015  1892.040039  1904.500000  1906.859985  4044900
# 2020-01-08  1911.000000  1886.439941  1898.040039  1891.969971  3508000
# ...                 ...          ...          ...          ...      ...
# 2020-10-21  3233.879883  3160.000000  3212.500000  3184.939941  4592700
# 2020-10-22  3198.750000  3121.939941  3189.870117  3176.399902  4212000
# 2020-10-23  3205.330078  3140.000000  3191.000000  3204.399902  3466700
# 2020-10-26  3282.979980  3153.300049  3198.739990  3207.040039  5901200
# 2020-10-27  3291.659912  3211.300049  3224.939941  3286.330078  4216400
#
#               Adj Close
# Date
# 2020-01-02  1898.010010
# 2020-01-03  1874.969971
# ...

# %%
amazon['Open'].plot(label = 'AMZN Open price', figsize=(15, 11))
amazon['Close'].plot(label = 'AMZN Close price')
amazon['High'].plot(label = 'AMZN High price')
amazon['Low'].plot(label = 'AMZN Low price')

# plt.figure(figsize=(10, 7)
plt.title('Amazon Stock Prices')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
amazon['Volume'].plot(figsize=(15, 7))

plt.title('Volume Traded by Amazon')
# Out:
# Text(0.5, 1.0, 'Volume Traded by Amazon')

# %% [markdown]
# ## Data Analysis

# %%
# Select a Datetime for exploring
start = datetime.datetime(2020, 1, 1)
end = datetime.datetime(2020, 10, 28)

# %%
# Amazon
amzn = web.DataReader('AMZN', 'yahoo', start, end)
# Google
goog = web.DataReader('GOOG', 'yahoo', start, end)
# Facebook
fb = web.DataReader('FB', 'yahoo', start, end)
# Microsoft
msft = web.DataReader('MSFT', 'yahoo', start, end)
# Apple
aapl = web.DataReader('AAPL', 'yahoo', start, end)

# %%
# Save Date
amzn.to_csv('AMZN_Stock.csv')
goog.to_csv('GOOG_Stock.csv')
fb.to_csv('FB_Stock.csv')
msft.to_csv('MSFT_Stock.csv')
aapl.to_csv('AAPL_Stock.csv')

# %%
amzn
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2020-01-02  1898.010010  1864.150024  1875.000000  1898.010010  4029000
# 2020-01-03  1886.199951  1864.500000  1864.500000  1874.969971  3764400
# 2020-01-06  1903.689941  1860.000000  1860.000000  1902.880005  4061800
# 2020-01-07  1913.890015  1892.040039  1904.500000  1906.859985  4044900
# 2020-01-08  1911.000000  1886.439941  1898.040039  1891.969971  3508000
# ...                 ...          ...          ...          ...      ...
# 2020-10-22  3198.750000  3121.939941  3189.870117  3176.399902  4212000
# 2020-10-23  3205.330078  3140.000000  3191.000000  3204.399902  3466700
# 2020-10-26  3282.979980  3153.300049  3198.739990  3207.040039  5901200
# 2020-10-27  3291.659912  3211.300049  3224.939941  3286.330078  4216400
# 2020-10-28  3263.989502  3195.550049  3224.939941  3197.443115   858398
#
#               Adj Close
# Date
# 2020-01-02  1898.010010
# 2020-01-03  1874.969971
# ...

# %%
goog
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2020-01-02  1368.140015  1341.550049  1341.550049  1367.369995  1406600
# 2020-01-03  1372.500000  1345.543945  1347.859985  1360.660034  1186400
# 2020-01-06  1396.500000  1350.000000  1350.000000  1394.209961  1732300
# 2020-01-07  1402.989990  1390.380005  1397.939941  1393.339966  1502700
# 2020-01-08  1411.579956  1390.839966  1392.079956  1404.319946  1528000
# ...                 ...          ...          ...          ...      ...
# 2020-10-22  1621.989990  1585.000000  1593.050049  1615.329956  1433600
# 2020-10-23  1642.359985  1620.510010  1626.069946  1641.000000  1375800
# 2020-10-26  1638.239990  1576.500000  1625.010010  1590.449951  1853300
# 2020-10-27  1606.844971  1582.780029  1595.670044  1604.260010  1209300
# 2020-10-28  1561.349976  1537.199951  1559.739990  1537.489990   262147
#
#               Adj Close
# Date
# 2020-01-02  1367.369995
# 2020-01-03  1360.660034
# ...

# %%
fb
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2020-01-02  209.789993  206.270004  206.750000  209.779999  12077100
# 2020-01-03  210.399994  206.949997  207.210007  208.669998  11188400
# 2020-01-06  212.779999  206.520004  206.699997  212.600006  17058900
# 2020-01-07  214.580002  211.750000  212.820007  213.059998  14912400
# 2020-01-08  216.240005  212.610001  213.000000  215.220001  13475000
# ...                ...         ...         ...         ...       ...
# 2020-10-22  282.450012  275.040009  279.869995  278.119995  16720000
# 2020-10-23  285.239990  276.820007  278.799988  284.790009  17535200
# 2020-10-26  285.230011  274.260010  283.160004  277.109985  21322900
# 2020-10-27  284.510010  276.309998  278.760010  283.290009  16164100
# 2020-10-28  278.399994  273.079987  278.760010  273.160004   3010330
#
#              Adj Close
# Date
# 2020-01-02  209.779999
# 2020-01-03  208.669998
# 2020-01-06  212.600006
# 2020-01-07  213.059998
# ...

# %%
msft
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2020-01-02  160.729996  158.330002  158.779999  160.619995  22622100.0
# 2020-01-03  159.949997  158.059998  158.320007  158.619995  21116200.0
# 2020-01-06  159.100006  156.509995  157.080002  159.029999  20813700.0
# 2020-01-07  159.669998  157.320007  159.320007  157.580002  21634100.0
# 2020-01-08  160.800003  157.949997  158.929993  160.089996  27746500.0
# ...                ...         ...         ...         ...         ...
# 2020-10-22  216.059998  211.699997  213.929993  214.889999  22351500.0
# 2020-10-23  216.279999  213.160004  215.029999  216.229996  18879600.0
# 2020-10-26  216.339996  208.100006  213.850006  210.080002  37111600.0
# 2020-10-27  214.669998  210.330002  211.589996  213.250000  35762400.0
# 2020-10-28  208.839996  206.500000  207.669998  206.690002   6926266.0
#
#              Adj Close
# Date
# 2020-01-02  159.352386
# 2020-01-03  157.368179
# 2020-01-06  157.774948
# ...

# %%
aapl
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2020-01-02   75.150002   73.797501   74.059998   75.087502  135480400.0
# 2020-01-03   75.144997   74.125000   74.287498   74.357498  146322800.0
# 2020-01-06   74.989998   73.187500   73.447502   74.949997  118387200.0
# 2020-01-07   75.224998   74.370003   74.959999   74.597504  108872000.0
# 2020-01-08   76.110001   74.290001   74.290001   75.797501  132079200.0
# ...                ...         ...         ...         ...          ...
# 2020-10-22  118.040001  114.589996  117.449997  115.750000  101988000.0
# 2020-10-23  116.550003  114.279999  116.389999  115.040001   82572600.0
# 2020-10-26  116.550003  112.879997  114.010002  115.050003  111850700.0
# 2020-10-27  117.279999  114.540001  115.489998  116.599998   91927700.0
# 2020-10-28  115.430000  113.070000  115.489998  113.180000   13755269.0
#
#              Adj Close
# Date
# 2020-01-02   74.573036
# 2020-01-03   73.848030
# ...

# %%
plt.figure(figsize=(15, 10))

amzn['Open'].plot(label = 'AMZN Open Price')
goog['Open'].plot(label = 'GOOG Open Price')
fb['Open'].plot(label = 'FB Open Price')
msft['Open'].plot(label = 'MSFT Open Price')
aapl['Open'].plot(label = 'AAPL Open Price')

plt.title('Stock Open Prices of the largest high tech companies in 2020')
plt.ylabel('Stock Prices')
plt.legend()
plt.show()

# %% [markdown]
# ### Volume Traded

# %%
plt.figure(figsize=(15, 10))

amzn['Volume'].plot(label = 'AMZN')
goog['Volume'].plot(label = 'GOOG')
fb['Volume'].plot(label = 'FB')
msft['Volume'].plot(label = 'MSFT')
aapl['Volume'].plot(label = 'AAPL')

plt.title('Volume Traded by the largest high tech companies in 2020')
plt.ylabel('Volume Traded')
plt.legend()
plt.show()

# %%
aapl.iloc[[aapl['Volume'].argmax()]]
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2020-02-28  69.602501  64.092499  64.315002  68.339996  426884800.0  68.032837

# %%
aapl.loc['2020-02-20':'2020-03-20']['Open'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Market Cap
#
# Total Traded Volume

# %%
amzn['Total Traded'] = amzn['Open'] * amzn['Volume']

# %%
amzn
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2020-01-02  1898.010010  1864.150024  1875.000000  1898.010010  4029000
# 2020-01-03  1886.199951  1864.500000  1864.500000  1874.969971  3764400
# 2020-01-06  1903.689941  1860.000000  1860.000000  1902.880005  4061800
# 2020-01-07  1913.890015  1892.040039  1904.500000  1906.859985  4044900
# 2020-01-08  1911.000000  1886.439941  1898.040039  1891.969971  3508000
# ...                 ...          ...          ...          ...      ...
# 2020-10-22  3198.750000  3121.939941  3189.870117  3176.399902  4212000
# 2020-10-23  3205.330078  3140.000000  3191.000000  3204.399902  3466700
# 2020-10-26  3282.979980  3153.300049  3198.739990  3207.040039  5901200
# 2020-10-27  3291.659912  3211.300049  3224.939941  3286.330078  4216400
# 2020-10-28  3263.989502  3195.550049  3224.939941  3197.443115   858398
#
#               Adj Close  Total Traded
# Date
# 2020-01-02  1898.010010  7.554375e+09
# ...

# %%
goog['Total Traded'] = goog['Open'] * goog['Volume']

goog
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2020-01-02  1368.140015  1341.550049  1341.550049  1367.369995  1406600
# 2020-01-03  1372.500000  1345.543945  1347.859985  1360.660034  1186400
# 2020-01-06  1396.500000  1350.000000  1350.000000  1394.209961  1732300
# 2020-01-07  1402.989990  1390.380005  1397.939941  1393.339966  1502700
# 2020-01-08  1411.579956  1390.839966  1392.079956  1404.319946  1528000
# ...                 ...          ...          ...          ...      ...
# 2020-10-22  1621.989990  1585.000000  1593.050049  1615.329956  1433600
# 2020-10-23  1642.359985  1620.510010  1626.069946  1641.000000  1375800
# 2020-10-26  1638.239990  1576.500000  1625.010010  1590.449951  1853300
# 2020-10-27  1606.844971  1582.780029  1595.670044  1604.260010  1209300
# 2020-10-28  1561.349976  1537.199951  1559.739990  1537.489990   262147
#
#               Adj Close  Total Traded
# Date
# 2020-01-02  1367.369995  1.887024e+09
# ...

# %%
fb['Total Traded'] = fb['Open'] * fb['Volume']

fb
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2020-01-02  209.789993  206.270004  206.750000  209.779999  12077100
# 2020-01-03  210.399994  206.949997  207.210007  208.669998  11188400
# 2020-01-06  212.779999  206.520004  206.699997  212.600006  17058900
# 2020-01-07  214.580002  211.750000  212.820007  213.059998  14912400
# 2020-01-08  216.240005  212.610001  213.000000  215.220001  13475000
# ...                ...         ...         ...         ...       ...
# 2020-10-22  282.450012  275.040009  279.869995  278.119995  16720000
# 2020-10-23  285.239990  276.820007  278.799988  284.790009  17535200
# 2020-10-26  285.230011  274.260010  283.160004  277.109985  21322900
# 2020-10-27  284.510010  276.309998  278.760010  283.290009  16164100
# 2020-10-28  278.399994  273.079987  278.760010  273.160004   3010330
#
#              Adj Close  Total Traded
# Date
# 2020-01-02  209.779999  2.496940e+09
# 2020-01-03  208.669998  2.318348e+09
# ...

# %%
msft['Total Traded'] = msft['Open'] * msft['Volume']

msft
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2020-01-02  160.729996  158.330002  158.779999  160.619995  22622100.0
# 2020-01-03  159.949997  158.059998  158.320007  158.619995  21116200.0
# 2020-01-06  159.100006  156.509995  157.080002  159.029999  20813700.0
# 2020-01-07  159.669998  157.320007  159.320007  157.580002  21634100.0
# 2020-01-08  160.800003  157.949997  158.929993  160.089996  27746500.0
# ...                ...         ...         ...         ...         ...
# 2020-10-22  216.059998  211.699997  213.929993  214.889999  22351500.0
# 2020-10-23  216.279999  213.160004  215.029999  216.229996  18879600.0
# 2020-10-26  216.339996  208.100006  213.850006  210.080002  37111600.0
# 2020-10-27  214.669998  210.330002  211.589996  213.250000  35762400.0
# 2020-10-28  208.839996  206.500000  207.669998  206.690002   6926266.0
#
#              Adj Close  Total Traded
# Date
# 2020-01-02  159.352386  3.591937e+09
# ...

# %%
aapl['Total Traded'] = aapl['Open'] * aapl['Volume']

aapl
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2020-01-02   75.150002   73.797501   74.059998   75.087502  135480400.0
# 2020-01-03   75.144997   74.125000   74.287498   74.357498  146322800.0
# 2020-01-06   74.989998   73.187500   73.447502   74.949997  118387200.0
# 2020-01-07   75.224998   74.370003   74.959999   74.597504  108872000.0
# 2020-01-08   76.110001   74.290001   74.290001   75.797501  132079200.0
# ...                ...         ...         ...         ...          ...
# 2020-10-22  118.040001  114.589996  117.449997  115.750000  101988000.0
# 2020-10-23  116.550003  114.279999  116.389999  115.040001   82572600.0
# 2020-10-26  116.550003  112.879997  114.010002  115.050003  111850700.0
# 2020-10-27  117.279999  114.540001  115.489998  116.599998   91927700.0
# 2020-10-28  115.430000  113.070000  115.489998  113.180000   13755269.0
#
#              Adj Close  Total Traded
# Date
# 2020-01-02   74.573036  1.003368e+10
# ...

# %%
plt.figure(figsize=(17, 13))

amzn['Total Traded'].plot(label='AMZN')
goog['Total Traded'].plot(label='GOOG')
fb['Total Traded'].plot(label='FB')
msft['Total Traded'].plot(label='MSFT')
aapl['Total Traded'].plot(label='AAPL')

plt.title('Total Traded Volume')
plt.legend()
plt.ylabel('Total Traded')
plt.show()

# %%
aapl['Total Traded'].argmax()
# Out:
# 162

# %%
aapl.iloc[[aapl['Total Traded'].argmax()]]
# Out:
#                   High       Low        Open       Close       Volume  \
# Date
# 2020-08-24  128.785004  123.9375  128.697495  125.857498  345937600.0
#
#              Adj Close  Total Traded
# Date
# 2020-08-24  125.857498  4.452130e+10

# %% [markdown]
# ### Moving Average
#
# A moving average (MA) is a stock indicator that is commonly used in technical analysis.
#
# The reason for calculating the moving average of a stock is to help smooth out the price data over a specified period of time by creating a constantly updated average price.
#
# A simple moving average (SMA) is a calculation that takes the arithmetic mean of a given set of prices over the specific number of days in the past; for example, over the previous 15, 30, 100, or 200 days.

# %%
goog['Open'].plot(figsize=(15, 7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
goog.loc['2020-02-01':'2020-05-06']['Open'].plot(figsize=(15, 7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
goog['Open'].plot(label = 'No Moving Average', figsize=(15, 9))
goog['MA15'] = goog['Open'].rolling(15).mean()
goog['MA15'].plot(label='MA15')
goog['MA50'] = goog['Open'].rolling(50).mean()
goog['MA50'].plot(label='MA50')
goog['MA100'] = goog['Open'].rolling(100).mean()
goog['MA100'].plot(label='MA100')

plt.legend()

# %% [markdown]
# ### Correlation & Scatter Matrix
#
# The statistical relationship between two variables is referred to as their correlation. A correlation could be positive, meaning both variables move in the same direction, or negative, meaning that when one variable's value increases, the other variables values decrease.
#
# A scatter plot matrix is a grid (or matrix) of scatter plots used to visualize bivariate relationships between combinations of variables. Each scatter plot in the matrix visualizes the relationship between a pair of variables, allowing many relationships to be explored in one chart.

# %%
from pandas.plotting import scatter_matrix

# %%
tech_comp = pd.concat([amzn['Open'], goog['Open'], fb['Open'], msft['Open'], aapl['Open']], axis=1)

tech_comp.columns = ['AMZN Open', 'GOOG Open', 'FB Open', 'MSFT Open', 'AAPL Open']

# %%
scatter_matrix(tech_comp, figsize=(17, 13), hist_kwds={'bins': 50})
# Out:
# array([[<AxesSubplot:xlabel='AMZN Open', ylabel='AMZN Open'>,
#         <AxesSubplot:xlabel='GOOG Open', ylabel='AMZN Open'>,
#         <AxesSubplot:xlabel='FB Open', ylabel='AMZN Open'>,
#         <AxesSubplot:xlabel='MSFT Open', ylabel='AMZN Open'>,
#         <AxesSubplot:xlabel='AAPL Open', ylabel='AMZN Open'>],
#        [<AxesSubplot:xlabel='AMZN Open', ylabel='GOOG Open'>,
#         <AxesSubplot:xlabel='GOOG Open', ylabel='GOOG Open'>,
#         <AxesSubplot:xlabel='FB Open', ylabel='GOOG Open'>,
#         <AxesSubplot:xlabel='MSFT Open', ylabel='GOOG Open'>,
#         <AxesSubplot:xlabel='AAPL Open', ylabel='GOOG Open'>],
#        [<AxesSubplot:xlabel='AMZN Open', ylabel='FB Open'>,
#         <AxesSubplot:xlabel='GOOG Open', ylabel='FB Open'>,
#         <AxesSubplot:xlabel='FB Open', ylabel='FB Open'>,
#         <AxesSubplot:xlabel='MSFT Open', ylabel='FB Open'>,
#         <AxesSubplot:xlabel='AAPL Open', ylabel='FB Open'>],
# ...

# %% [markdown]
# ### Candlestick Charts
#
# A candlestick is a type of price chart used in technical analysis that displays the high, low, open, and closing prices of a security for a specific period.

# %%
from mpl_finance import candlestick_ohlc
from matplotlib.dates import DateFormatter, date2num, WeekdayLocator, DayLocator, MONDAY

# %%
plt.figure(figsize=(15, 10))

aapl_reset = aapl.loc['2020-08':'2020-09'].reset_index()

aapl_reset['date_ax'] = aapl_reset['Date'].apply(lambda date: date2num(date))
aapl_values = [tuple(vals) for vals in aapl_reset[['date_ax', 'Open', 'High', 'Low', 'Close']].values]

mondays = WeekdayLocator(MONDAY)
alldays = DayLocator()
week_formatter = DateFormatter('%b %d')
day_formatter = DateFormatter('%d')

fig, ax = plt.subplots(figsize=(15, 10))
candlestick_ohlc(ax, aapl_values, width=0.7, colorup='g', colordown='r')
# Out:
# ([<matplotlib.lines.Line2D at 0x137cf7400>,
# ...
#   <matplotlib.patches.Rectangle at 0x139c0ed60>])

# %% [markdown]
# ### Daily Percentage Change
#
# ### $r_t = \frac{p_t}{p_t-1} - 1$
#
# Percentage change represents a degree of change over time; it is used for many purposes in finance, most notably to indicate the price change of a security.
# Percentage change can be applied to any quantity that can be measured over time.
# Positive values indicate a percentage increase whereas negative values indicate percentage decrease.

# %%
# Which stock is the most stable?

amzn['Returns'] = (amzn['Close'] / amzn['Close'].shift(1)) - 1

amzn
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2020-01-02  1898.010010  1864.150024  1875.000000  1898.010010  4029000
# 2020-01-03  1886.199951  1864.500000  1864.500000  1874.969971  3764400
# 2020-01-06  1903.689941  1860.000000  1860.000000  1902.880005  4061800
# 2020-01-07  1913.890015  1892.040039  1904.500000  1906.859985  4044900
# 2020-01-08  1911.000000  1886.439941  1898.040039  1891.969971  3508000
# ...                 ...          ...          ...          ...      ...
# 2020-10-22  3198.750000  3121.939941  3189.870117  3176.399902  4212000
# 2020-10-23  3205.330078  3140.000000  3191.000000  3204.399902  3466700
# 2020-10-26  3282.979980  3153.300049  3198.739990  3207.040039  5901200
# 2020-10-27  3291.659912  3211.300049  3224.939941  3286.330078  4216400
# 2020-10-28  3263.989502  3195.550049  3224.939941  3197.443115   858398
#
#               Adj Close  Total Traded   Returns
# Date
# ...

# %%
goog['Returns'] = (goog['Close'] / goog['Close'].shift(1)) - 1

goog
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2020-01-02  1368.140015  1341.550049  1341.550049  1367.369995  1406600
# 2020-01-03  1372.500000  1345.543945  1347.859985  1360.660034  1186400
# 2020-01-06  1396.500000  1350.000000  1350.000000  1394.209961  1732300
# 2020-01-07  1402.989990  1390.380005  1397.939941  1393.339966  1502700
# 2020-01-08  1411.579956  1390.839966  1392.079956  1404.319946  1528000
# ...                 ...          ...          ...          ...      ...
# 2020-10-22  1621.989990  1585.000000  1593.050049  1615.329956  1433600
# 2020-10-23  1642.359985  1620.510010  1626.069946  1641.000000  1375800
# 2020-10-26  1638.239990  1576.500000  1625.010010  1590.449951  1853300
# 2020-10-27  1606.844971  1582.780029  1595.670044  1604.260010  1209300
# 2020-10-28  1561.349976  1537.199951  1559.739990  1537.489990   262147
#
#               Adj Close  Total Traded         MA50         MA70        MA200  \
# Date
# ...

# %%
fb['Returns'] = (fb['Close'] / fb['Close'].shift(1)) - 1

fb
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2020-01-02  209.789993  206.270004  206.750000  209.779999  12077100
# 2020-01-03  210.399994  206.949997  207.210007  208.669998  11188400
# 2020-01-06  212.779999  206.520004  206.699997  212.600006  17058900
# 2020-01-07  214.580002  211.750000  212.820007  213.059998  14912400
# 2020-01-08  216.240005  212.610001  213.000000  215.220001  13475000
# ...                ...         ...         ...         ...       ...
# 2020-10-22  282.450012  275.040009  279.869995  278.119995  16720000
# 2020-10-23  285.239990  276.820007  278.799988  284.790009  17535200
# 2020-10-26  285.230011  274.260010  283.160004  277.109985  21322900
# 2020-10-27  284.510010  276.309998  278.760010  283.290009  16164100
# 2020-10-28  278.399994  273.079987  278.760010  273.160004   3010330
#
#              Adj Close  Total Traded   Returns
# Date
# 2020-01-02  209.779999  2.496940e+09       NaN
# ...

# %%
msft['Returns'] = (msft['Close'] / msft['Close'].shift(1)) - 1

msft
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2020-01-02  160.729996  158.330002  158.779999  160.619995  22622100.0
# 2020-01-03  159.949997  158.059998  158.320007  158.619995  21116200.0
# 2020-01-06  159.100006  156.509995  157.080002  159.029999  20813700.0
# 2020-01-07  159.669998  157.320007  159.320007  157.580002  21634100.0
# 2020-01-08  160.800003  157.949997  158.929993  160.089996  27746500.0
# ...                ...         ...         ...         ...         ...
# 2020-10-22  216.059998  211.699997  213.929993  214.889999  22351500.0
# 2020-10-23  216.279999  213.160004  215.029999  216.229996  18879600.0
# 2020-10-26  216.339996  208.100006  213.850006  210.080002  37111600.0
# 2020-10-27  214.669998  210.330002  211.589996  213.250000  35762400.0
# 2020-10-28  208.839996  206.500000  207.669998  206.690002   6926266.0
#
#              Adj Close  Total Traded   Returns
# Date
# 2020-01-02  159.352386  3.591937e+09       NaN
# ...

# %%
aapl['Returns'] = (aapl['Close'] / aapl['Close'].shift(1)) - 1

aapl
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2020-01-02   75.150002   73.797501   74.059998   75.087502  135480400.0
# 2020-01-03   75.144997   74.125000   74.287498   74.357498  146322800.0
# 2020-01-06   74.989998   73.187500   73.447502   74.949997  118387200.0
# 2020-01-07   75.224998   74.370003   74.959999   74.597504  108872000.0
# 2020-01-08   76.110001   74.290001   74.290001   75.797501  132079200.0
# ...                ...         ...         ...         ...          ...
# 2020-10-22  118.040001  114.589996  117.449997  115.750000  101988000.0
# 2020-10-23  116.550003  114.279999  116.389999  115.040001   82572600.0
# 2020-10-26  116.550003  112.879997  114.010002  115.050003  111850700.0
# 2020-10-27  117.279999  114.540001  115.489998  116.599998   91927700.0
# 2020-10-28  115.430000  113.070000  115.489998  113.180000   13755269.0
#
#              Adj Close  Total Traded   Returns
# Date
# ...

# %% [markdown]
# ### Volatility
#
# The volatility of a stock is a measurement of the amount of change of variance in the price of a stock over a specific time-period. It is common to compare the volatility of a stock to another stock to get a feel for which may have less risk, or to a market index to compare the stock's volatility to the overall market.
#
# Generally, the higher the volatility, the riskier the investment is in that stock.

# %%
amzn['Returns'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
goog['Returns'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
fb['Returns'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
msft['Returns'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
aapl['Returns'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(17, 12))

amzn['Returns'].hist(bins=100, label='AMZN', alpha=0.5)
goog['Returns'].hist(bins=100, label='GOOG', alpha=0.5)
fb['Returns'].hist(bins=100, label='FB', alpha=0.5)
msft['Returns'].hist(bins=100, label='MSFT', alpha=0.5)
aapl['Returns'].hist(bins=100, label='AAPL', alpha=0.5)

plt.legend()

# %% [markdown]
# ### KDE plot
#
# A kernel density estimate (KDE) plot is a method for visualizing the distribution of observations in a dataset, analagous to a histogram. KDE represents the data using a continuous probability density curve in one or more dimensions.
#
# Probability density function (PDF) is a statistical expression that defines a probability distribution (the likelihood of an outcome) for a discrete random variable (e.g., a stock or ETF) as opposed to a continuous random variable.

# %%
plt.figure(figsize=(17, 12))

amzn['Returns'].plot(kind='kde', label='AMZN')
goog['Returns'].plot(kind='kde', label='GOOG')
fb['Returns'].plot(kind='kde', label='FB')
msft['Returns'].plot(kind='kde', label='MSFT')
aapl['Returns'].plot(kind='kde', label='AAPL')

plt.legend()

# %% [markdown]
# ### Box Plots
#
# A box plot (also known as box and whisker plot) is a type of chart often used in explanatory data analysis to visually show the distribution of numerical data and skewness through displaying the data quartiles (or percentiles) and averages.

# %%
bbox_df = pd.concat([amzn['Returns'], goog['Returns'], fb['Returns'], msft['Returns'], aapl['Returns']], axis=1)
box_df.columns = ['AMZN Returns', 'GOOG Returns', 'FB Returns', 'MSFT Returns', 'AAPL Returns']

box_df.plot(kind='box', figsize=(15, 10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Volatility & Stability

# %%
scatter_matrix(box_df, figsize=(17, 12), hist_kwds={'bins': 50}, alpha=0.3)
# Out:
# array([[<AxesSubplot:xlabel='AMZN Returns', ylabel='AMZN Returns'>,
#         <AxesSubplot:xlabel='GOOG Returns', ylabel='AMZN Returns'>,
#         <AxesSubplot:xlabel='FB Returns', ylabel='AMZN Returns'>,
#         <AxesSubplot:xlabel='MSFT Returns', ylabel='AMZN Returns'>,
#         <AxesSubplot:xlabel='AAPL Returns', ylabel='AMZN Returns'>],
#        [<AxesSubplot:xlabel='AMZN Returns', ylabel='GOOG Returns'>,
#         <AxesSubplot:xlabel='GOOG Returns', ylabel='GOOG Returns'>,
#         <AxesSubplot:xlabel='FB Returns', ylabel='GOOG Returns'>,
#         <AxesSubplot:xlabel='MSFT Returns', ylabel='GOOG Returns'>,
#         <AxesSubplot:xlabel='AAPL Returns', ylabel='GOOG Returns'>],
#        [<AxesSubplot:xlabel='AMZN Returns', ylabel='FB Returns'>,
#         <AxesSubplot:xlabel='GOOG Returns', ylabel='FB Returns'>,
#         <AxesSubplot:xlabel='FB Returns', ylabel='FB Returns'>,
#         <AxesSubplot:xlabel='MSFT Returns', ylabel='FB Returns'>,
# ...

# %% [markdown]
# ## Cumulative Return
#
# Cumulative returns express the total percentage increase in the value of an investment from the time it was purchased.
#
# The cumulative return is the total change in the investment price over a set time—an aggregate return, not an annualized one. Reinvesting the dividends or capital gains of an investment impacts its cumulative return.
#
#
# ### $r_t = \frac{p_t}{p_t-1} - 1$
# ### $i_t = (1 + r_t) * i_t-1 = \frac{p_t}{p_t-1} * i_t-1$

# %%
amzn['Cumulative Return'] = (1 + amzn['Returns']).cumprod()

amzn
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2020-01-02  1898.010010  1864.150024  1875.000000  1898.010010  4029000
# 2020-01-03  1886.199951  1864.500000  1864.500000  1874.969971  3764400
# 2020-01-06  1903.689941  1860.000000  1860.000000  1902.880005  4061800
# 2020-01-07  1913.890015  1892.040039  1904.500000  1906.859985  4044900
# 2020-01-08  1911.000000  1886.439941  1898.040039  1891.969971  3508000
# ...                 ...          ...          ...          ...      ...
# 2020-10-22  3198.750000  3121.939941  3189.870117  3176.399902  4212000
# 2020-10-23  3205.330078  3140.000000  3191.000000  3204.399902  3466700
# 2020-10-26  3282.979980  3153.300049  3198.739990  3207.040039  5901200
# 2020-10-27  3291.659912  3211.300049  3224.939941  3286.330078  4216400
# 2020-10-28  3263.989502  3195.550049  3224.939941  3197.443115   858398
#
#               Adj Close  Total Traded   Returns  Cumulative Return
# Date
# ...

# %%
goog['Cumulative Return'] = (1 + goog['Returns']).cumprod()
fb['Cumulative Return'] = (1 + fb['Returns']).cumprod()
msft['Cumulative Return'] = (1 + msft['Returns']).cumprod()
aapl['Cumulative Return'] = (1 + aapl['Returns']).cumprod()

# %%
plt.figure(figsize=(17, 12))

amzn['Cumulative Return'].plot(label='AMZN')
goog['Cumulative Return'].plot(label='GOOG')
fb['Cumulative Return'].plot(label='FB')
msft['Cumulative Return'].plot(label='MSFT')
aapl['Cumulative Return'].plot(label='AAPL')

plt.title('Cumulative Return vs Time')
plt.legend()
