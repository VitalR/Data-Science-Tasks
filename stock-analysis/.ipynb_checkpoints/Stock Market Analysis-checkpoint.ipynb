# %% [markdown]
# ## Step 1: Importing Datasets

# %%
import pandas as pd


# https://finance.yahoo.com/quote/AMZN/history?period1=1287532800&period2=1603152000&interval=1mo&filter=history&frequency=1mo&includeAdjustedClose=true
amzn = pd.read_csv('AMZN_10y_monthly_data.csv')

amzn
# Out:
#            Date         Open         High          Low        Close  \
# 0    2010-11-01   164.449997   181.839996   156.770004   175.399994
# 1    2010-12-01   179.160004   185.649994   173.089996   180.000000
# 2    2011-01-01   181.369995   191.600006   166.899994   169.639999
# 3    2011-02-01   170.520004   191.399994   169.509995   173.289993
# 4    2011-03-01   173.529999   181.570007   160.589996   180.130005
# ..          ...          ...          ...          ...          ...
# 116  2020-07-01  2757.989990  3344.290039  2754.000000  3164.679932
# 117  2020-08-01  3180.510010  3495.000000  3073.000000  3450.959961
# 118  2020-09-01  3489.580078  3552.250000  2871.000000  3148.729980
# 119  2020-10-01  3208.000000  3496.239990  3090.000000  3207.209961
# 120  2020-10-19  3299.610107  3329.000000  3192.989990  3207.209961
#
#        Adj Close     Volume
# 0     175.399994  131011400
# 1     180.000000   93661700
# 2     169.639999  113611300
# 3     173.289993   95776400
# ...

# %%
amzn = pd.read_csv('AMZN_10y_monthly_data.csv', header=0, index_col='Date', parse_dates=True)

amzn
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2010-11-01   164.449997   181.839996   156.770004   175.399994   175.399994
# 2010-12-01   179.160004   185.649994   173.089996   180.000000   180.000000
# 2011-01-01   181.369995   191.600006   166.899994   169.639999   169.639999
# 2011-02-01   170.520004   191.399994   169.509995   173.289993   173.289993
# 2011-03-01   173.529999   181.570007   160.589996   180.130005   180.130005
# ...                 ...          ...          ...          ...          ...
# 2020-07-01  2757.989990  3344.290039  2754.000000  3164.679932  3164.679932
# 2020-08-01  3180.510010  3495.000000  3073.000000  3450.959961  3450.959961
# 2020-09-01  3489.580078  3552.250000  2871.000000  3148.729980  3148.729980
# 2020-10-01  3208.000000  3496.239990  3090.000000  3207.209961  3207.209961
# 2020-10-19  3299.610107  3329.000000  3192.989990  3207.209961  3207.209961
#
#                Volume
# Date
# ...

# %%
amzn.head(3)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-11-01  164.449997  181.839996  156.770004  175.399994  175.399994
# 2010-12-01  179.160004  185.649994  173.089996  180.000000  180.000000
# 2011-01-01  181.369995  191.600006  166.899994  169.639999  169.639999
#
#                Volume
# Date
# 2010-11-01  131011400
# 2010-12-01   93661700
# 2011-01-01  113611300

# %%
amzn.tail()
# Out:
#                    Open         High         Low        Close    Adj Close  \
# Date
# 2020-07-01  2757.989990  3344.290039  2754.00000  3164.679932  3164.679932
# 2020-08-01  3180.510010  3495.000000  3073.00000  3450.959961  3450.959961
# 2020-09-01  3489.580078  3552.250000  2871.00000  3148.729980  3148.729980
# 2020-10-01  3208.000000  3496.239990  3090.00000  3207.209961  3207.209961
# 2020-10-19  3299.610107  3329.000000  3192.98999  3207.209961  3207.209961
#
#                Volume
# Date
# 2020-07-01  127515700
# 2020-08-01   83528700
# 2020-09-01  115930800
# 2020-10-01   68684700
# 2020-10-19    5223626

# %% [markdown]
# ## Using Pandas DataReader

# %%
import pandas_datareader as pdr
import datetime

# %%
fb = pdr.get_data_yahoo('FB', start=datetime.datetime(2010,11,1), end=datetime.datetime(2020,10,19))

fb
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2012-05-18   45.000000   38.000000   42.049999   38.230000  573576400
# 2012-05-21   36.660000   33.000000   36.529999   34.029999  168192700
# 2012-05-22   33.590000   30.940001   32.610001   31.000000  101786600
# 2012-05-23   32.500000   31.360001   31.370001   32.000000   73600000
# 2012-05-24   33.209999   31.770000   32.950001   33.029999   50237200
# ...                ...         ...         ...         ...        ...
# 2020-10-13  279.100006  273.390015  277.579987  276.140015   18063300
# 2020-10-14  278.750000  271.500000  277.619995  271.820007   15601200
# 2020-10-15  269.040009  263.670013  267.600006  266.720001   15416100
# 2020-10-16  271.369995  265.299988  267.380005  265.929993   16622700
# 2020-10-19  268.549988  259.880005  265.529999  261.399994   13573300
#
#              Adj Close
# Date
# 2012-05-18   38.230000
# 2012-05-21   34.029999
# 2012-05-22   31.000000
# ...

# %%
aapl = pdr.get_data_yahoo('AAPL', start=datetime.datetime(2010,11,1), end=datetime.datetime(2020,10,19))

aapl
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2010-11-01   10.914286   10.792857   10.793571   10.863571  423889200.0
# 2010-11-02   11.078215   10.964286   10.964286   11.048572  433930000.0
# 2010-11-03   11.174286   11.018929   11.120358   11.171429  508348400.0
# 2010-11-04   11.435000   11.251071   11.266071   11.366786  642488000.0
# 2010-11-05   11.413215   11.312500   11.356786   11.326072  361253200.0
# ...                ...         ...         ...         ...          ...
# 2020-10-13  125.389999  119.650002  125.269997  121.099998  262330500.0
# 2020-10-14  123.029999  119.620003  121.000000  121.190002  151062300.0
# 2020-10-15  121.199997  118.150002  118.720001  120.709999  112559200.0
# 2020-10-16  121.550003  118.809998  121.279999  119.019997  115393800.0
# 2020-10-19  120.419998  115.660004  119.959999  115.980003  120221600.0
#
#              Adj Close
# Date
# 2010-11-01    9.387636
# 2010-11-02    9.547504
# ...

# %%
goog = pdr.get_data_yahoo('GOOG', start=datetime.datetime(2010,11,1), end=datetime.datetime(2020,10,19))

goog
# Out:
#                    High          Low         Open        Close     Volume  \
# Date
# 2010-11-01   309.171143   304.463806   306.715363   306.351715  6197200.0
# 2010-11-02   308.842377   306.142517   308.179871   306.650604  4010000.0
# 2010-11-03   309.753967   305.604523   307.597046   308.932037  6786200.0
# 2010-11-04   313.783875   309.888458   311.153717   310.969421  7168300.0
# 2010-11-05   311.577118   309.395325   310.426453   311.372894  3544600.0
# ...                 ...          ...          ...          ...        ...
# 2020-10-13  1590.000000  1563.199951  1583.729980  1571.680054  1601000.0
# 2020-10-14  1587.683960  1550.530029  1578.589966  1568.079956  1931000.0
# 2020-10-15  1575.104980  1545.030029  1547.150024  1559.130005  1540000.0
# 2020-10-16  1581.130005  1563.000000  1565.849976  1573.010010  1434700.0
# 2020-10-19  1588.150024  1528.000000  1580.459961  1534.609985  1606500.0
#
#               Adj Close
# Date
# 2010-11-01   306.351715
# ...

# %%
tsla = pdr.get_data_yahoo('TSLA', start=datetime.datetime(2010,11,1), end=datetime.datetime(2020,10,19))

tsla
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2010-11-01    4.550000    4.262000    4.388000    4.282000   2279000.0
# 2010-11-02    4.376000    4.210000    4.336000    4.250000   1612500.0
# 2010-11-03    4.500000    4.232000    4.256000    4.354000   1863000.0
# 2010-11-04    5.066000    4.430000    4.520000    4.980000   9370000.0
# 2010-11-05    4.994000    4.744000    4.974000    4.888000   5055000.0
# ...                ...         ...         ...         ...         ...
# 2020-10-13  448.890015  436.600006  443.350006  446.649994  34463700.0
# 2020-10-14  465.899994  447.350006  449.779999  461.299988  48045400.0
# 2020-10-15  456.570007  442.500000  450.309998  448.880005  35672400.0
# 2020-10-16  455.950012  438.850006  454.440002  439.670013  32775900.0
# 2020-10-19  447.000000  428.869995  446.239990  430.829987  36124500.0
#
#              Adj Close
# Date
# 2010-11-01    4.282000
# 2010-11-02    4.250000
# 2010-11-03    4.354000
# ...

# %%
type(fb), type(aapl), type(goog), type(tsla)
# Out:
# (pandas.core.frame.DataFrame,
#  pandas.core.frame.DataFrame,
#  pandas.core.frame.DataFrame,
#  pandas.core.frame.DataFrame)

# %%
goog.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  2509.000000  2509.000000  2509.000000  2509.000000  2.509000e+03
# mean    744.715984   731.201673   738.002366   738.215580  2.905472e+06
# std     371.057488   363.133818   366.854833   367.326887  2.374491e+06
# min     239.477386   235.626816   236.114990   236.553345  7.900000e+03
# 25%     418.506348   413.241058   415.691895   415.851288  1.389600e+06
# 50%     680.330017   663.283997   671.000000   675.219971  1.994500e+06
# 75%    1075.560059  1049.500000  1063.030029  1065.000000  3.911900e+06
# max    1733.180054  1666.329956  1709.713989  1728.280029  2.819250e+07
#
#          Adj Close
# count  2509.000000
# mean    738.215580
# std     367.326887
# min     236.553345
# 25%     415.851288
# 50%     675.219971
# 75%    1065.000000
# max    1728.280029

# %%
tsla.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
tsla.index, goog.index
# Out:
# (DatetimeIndex(['2010-11-01', '2010-11-02', '2010-11-03', '2010-11-04',
#                 '2010-11-05', '2010-11-08', '2010-11-09', '2010-11-10',
#                 '2010-11-11', '2010-11-12',
#                 ...
#                 '2020-10-06', '2020-10-07', '2020-10-08', '2020-10-09',
#                 '2020-10-12', '2020-10-13', '2020-10-14', '2020-10-15',
#                 '2020-10-16', '2020-10-19'],
#                dtype='datetime64[ns]', name='Date', length=2509, freq=None),
#  DatetimeIndex(['2010-11-01', '2010-11-02', '2010-11-03', '2010-11-04',
#                 '2010-11-05', '2010-11-08', '2010-11-09', '2010-11-10',
#                 '2010-11-11', '2010-11-12',
#                 ...
#                 '2020-10-06', '2020-10-07', '2020-10-08', '2020-10-09',
#                 '2020-10-12', '2020-10-13', '2020-10-14', '2020-10-15',
#                 '2020-10-16', '2020-10-19'],
#                dtype='datetime64[ns]', name='Date', length=2509, freq=None))

# %%
tsla.shape
# Out:
# (2509, 6)

# %% [markdown]
# ## Time Series Data
#
# A time series is a sequence of numerical data points taken at successive equally spaced points in time.
# In investing, a time series tracks the movement of the stock price, over a specified period of time.

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %matplotlib inline

# %%
plt.plot(amzn.index, amzn['Adj Close'])

plt.show()

# %%
plt.plot(amzn.index, amzn['Adj Close'])
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.grid(True)
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# ### Subplots

# %%
fig, axes = plt.subplots(2, 2, figsize=(10,10), sharex=True)
fig.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
fig.gca().xaxis.set_major_locator(mdates.YearLocator())

axes[0,0].plot(amzn.index, amzn['Adj Close'], color='r')
axes[0,0].grid(True)
axes[0,0].tick_params(labelrotation=90)
axes[0,0].set_title('AMZN');

axes[0,1].plot(fb.index, fb['Adj Close'], color='g')
axes[0,1].grid(True)
axes[0,1].tick_params(labelrotation=90)
axes[0,1].set_title('FB');

axes[1,0].plot(goog.index, goog['Adj Close'], color='b')
axes[1,0].grid(True)
axes[1,0].tick_params(labelrotation=90)
axes[1,0].set_title('GOOG');

axes[1,1].plot(aapl.index, aapl['Adj Close'], color='y')
axes[1,1].grid(True)
axes[1,1].tick_params(labelrotation=90)
axes[1,1].set_title('AAPL');

# %% [markdown]
# ### Zooming-in

# %%
amzn_19_20 = amzn.loc[pd.Timestamp('2019-01-01'):pd.Timestamp('2020-10-01')]
plt.plot(amzn_19_20.index, amzn_19_20['Adj Close'])
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %%
# Sublots
fig, axes = plt.subplots(2, 2, figsize=(30,25), sharex=True, sharey=True)
fig.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
fig.gca().xaxis.set_major_locator(mdates.MonthLocator())

amzn_19_20 = amzn.loc[pd.Timestamp('2019-01-01'):pd.Timestamp('2020-10-01')]
axes[0,0].plot(amzn_19_20.index, amzn_19_20['Adj Close'], '.', color='r')
axes[0,0].grid(True)
axes[0,0].tick_params(labelrotation=90)
axes[0,0].set_title('AMZN');

fb_19_20 = fb.loc[pd.Timestamp('2019-01-01'):pd.Timestamp('2020-10-01')]
axes[0,1].plot(fb_19_20.index, fb_19_20['Adj Close'], '.', color='g')
axes[0,1].grid(True)
axes[0,1].tick_params(labelrotation=90)
axes[0,1].set_title('FB');

goog_19_20 = goog.loc[pd.Timestamp('2019-01-01'):pd.Timestamp('2020-10-01')]
axes[1,0].plot(goog_19_20.index, goog_19_20['Adj Close'], '.', color='b')
axes[1,0].grid(True)
axes[1,0].tick_params(labelrotation=90)
axes[1,0].set_title('GOOG');

aapl_19_20 = aapl.loc[pd.Timestamp('2019-01-01'):pd.Timestamp('2020-10-01')]
axes[1,1].plot(aapl_19_20.index, aapl_19_20['Adj Close'], '.', color='y')
axes[1,1].grid(True)
axes[1,1].tick_params(labelrotation=90)
axes[1,1].set_title('AALP');

# %% [markdown]
# ## Step 2: Resampling (Quarterly)

# %%
monthly_amzn_19_20 = amzn_19_20.resample('4M').mean()
plt.scatter(monthly_amzn_19_20.index, monthly_amzn_19_20['Adj Close'])
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %%
# Subplots
fix, axes = plt.subplots(2, 2, figsize=(10,10), sharex=True, sharey=True)

monthly_amzn_19_20 = amzn_19_20.resample('4M').mean()
axes[0,0].scatter(monthly_amzn_19_20.index, monthly_amzn_19_20['Adj Close'], color='r')
axes[0,0].grid(True)
axes[0,0].tick_params(labelrotation=90)
axes[0,0].set_title('AMZN');

monthly_fb_19_20 = fb_19_20.resample('4M').mean()
axes[0,1].scatter(monthly_fb_19_20.index, monthly_fb_19_20['Adj Close'], color='g')
axes[0,1].grid(True)
axes[0,1].tick_params(labelrotation=90)
axes[0,1].set_title('FB');

monthly_goog_19_20 = fb_19_20.resample('4M').mean()
axes[1,0].scatter(monthly_goog_19_20.index, monthly_goog_19_20['Adj Close'], color='b')
axes[1,0].grid(True)
axes[1,0].tick_params(labelrotation=90)
axes[1,0].set_title('GOOG');

monthly_aapl_19_20 = fb_19_20.resample('4M').mean()
axes[1,1].scatter(monthly_aapl_19_20.index, monthly_aapl_19_20['Adj Close'], color='y')
axes[1,1].grid(True)
axes[1,1].tick_params(labelrotation=90)
axes[1,1].set_title('AAPL');

# %% [markdown]
# ### Resampling Weekly

# %%
amzn_20 = amzn.loc[pd.Timestamp('2019-01-01'):pd.Timestamp('2020-10-01')]

# %%
weekly_amzn_20 = amzn_20.resample('W').mean()
weekly_amzn_20.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-01-06  1465.199951  1736.410034  1460.930054  1718.729980  1718.729980
# 2019-01-13          NaN          NaN          NaN          NaN          NaN
# 2019-01-20          NaN          NaN          NaN          NaN          NaN
# 2019-01-27          NaN          NaN          NaN          NaN          NaN
# 2019-02-03  1638.880005  1673.060059  1566.760010  1639.829956  1639.829956
#
#                  Volume
# Date
# 2019-01-06  134001700.0
# 2019-01-13          NaN
# 2019-01-20          NaN
# 2019-01-27          NaN
# 2019-02-03   80936900.0

# %%
plt.plot(weekly_amzn_20.index, weekly_amzn_20['Adj Close'], '-o')
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %%
# Subplots

amzn_20 = amzn.loc[pd.Timestamp('2020-01-01'):pd.Timestamp('2020-10-01')]
weekly_amzn_20 = amzn_20.resample('W').mean()

fb_20 = fb.loc[pd.Timestamp('2020-01-01'):pd.Timestamp('2020-10-01')]
weekly_fb_20 = fb_20.resample('W').mean()

goog_20 = goog.loc[pd.Timestamp('2020-01-01'):pd.Timestamp('2020-10-01')]
weekly_goog_20 = goog_20.resample('W').mean()

aapl_20 = aapl.loc[pd.Timestamp('2020-01-01'):pd.Timestamp('2020-10-01')]
weekly_aapl_20 = aapl_20.resample('W').mean()


f, ax = plt.subplots(2, 2, figsize=(10,10), sharex=True, sharey=True)

ax[0,0].plot(weekly_amzn_20.index, weekly_amzn_20['Adj Close'], '.', color='r')
ax[0,0].grid(True)
ax[0,0].tick_params(labelrotation=90)
ax[0,0].set_title('AMZN');

ax[0,1].plot(weekly_fb_20.index, weekly_fb_20['Adj Close'], '.', color='g')
ax[0,1].grid(True)
ax[0,1].tick_params(labelrotation=90)
ax[0,1].set_title('FB');

ax[1,0].plot(weekly_goog_20.index, weekly_goog_20['Adj Close'], '.', color='b')
ax[1,0].grid(True)
ax[1,0].tick_params(labelrotation=90)
ax[1,0].set_title('GOOG');

ax[1,1].plot(weekly_aapl_20.index, weekly_aapl_20['Adj Close'], '.', color='y')
ax[1,1].grid(True)
ax[1,1].tick_params(labelrotation=90)
ax[1,1].set_title('AAPL');

# %% [markdown]
# ### Analysing Difference between Levels (Resampling Weekly)

# %%
amzn['Difference'] = amzn['Open'] - amzn['Close']
amzn_diff = amzn.resample('W').mean()
amzn_diff
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2010-11-07   164.449997   181.839996   156.770004   175.399994   175.399994
# 2010-11-14          NaN          NaN          NaN          NaN          NaN
# 2010-11-21          NaN          NaN          NaN          NaN          NaN
# 2010-11-28          NaN          NaN          NaN          NaN          NaN
# 2010-12-05   179.160004   185.649994   173.089996   180.000000   180.000000
# ...                 ...          ...          ...          ...          ...
# 2020-09-27          NaN          NaN          NaN          NaN          NaN
# 2020-10-04  3208.000000  3496.239990  3090.000000  3207.209961  3207.209961
# 2020-10-11          NaN          NaN          NaN          NaN          NaN
# 2020-10-18          NaN          NaN          NaN          NaN          NaN
# 2020-10-25  3299.610107  3329.000000  3192.989990  3207.209961  3207.209961
#
#                  Volume  Difference
# Date
# ...

# %%
plt.scatter(amzn_diff.loc['2020-01-01':'2020-10-01'].index, amzn_diff.loc['2020-01-01':'2020-10-01']['Difference'])
# plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %%
# Subplot

fb['Difference'] = fb['Open'] - fb['Close']
fb_diff = fb.resample('W').mean()

goog['Difference'] = goog['Open'] - goog['Close']
goog_diff = goog.resample('W').mean()

aapl['Difference'] = aapl['Open'] - aapl['Close']
aapl_diff = aapl.resample('W').mean()


f, ax = plt.subplots(2, 2, figsize=(10,10), sharex=True, sharey=True)

ax[0,0].scatter(amzn_diff.loc['2020-01-01':'2020-10-01'].index, amzn_diff.loc['2020-01-01':'2020-10-01']['Difference'], color='r')
ax[0,0].grid(True)
ax[0,0].tick_params(labelrotation=90)
ax[0,0].set_title('AMZN');

ax[0,1].scatter(fb_diff.loc['2020-01-01':'2020-10-01'].index, fb_diff.loc['2020-01-01':'2020-10-01']['Difference'], color='g')
ax[0,1].grid(True)
ax[0,1].tick_params(labelrotation=90)
ax[0,1].set_title('FB');

ax[1,0].scatter(goog_diff.loc['2020-01-01':'2020-10-01'].index, goog_diff.loc['2020-01-01':'2020-10-01']['Difference'], color='b')
ax[1,0].grid(True)
ax[1,0].tick_params(labelrotation=90)
ax[1,0].set_title('GOOG');

ax[1,1].scatter(aapl_diff.loc['2020-01-01':'2020-10-01'].index, aapl_diff.loc['2020-01-01':'2020-10-01']['Difference'], color='y')
ax[1,1].grid(True)
ax[1,1].tick_params(labelrotation=90)
ax[1,1].set_title('AAPL');

# %% [markdown]
# ## Step 3: Moving Windows
#
# ### Daily Percentages

# %%
# AMZN
daily_close_amzn = amzn[['Adj Close']]

# Daily returns
daily_pct_changes_amzn = daily_close_amzn.pct_change()

# Replace NA value with 0
daily_pct_changes_amzn.fillna(0, inplace=True)

daily_pct_changes_amzn
# Out:
#             Adj Close
# Date
# 2010-11-01   0.000000
# 2010-12-01   0.026226
# 2011-01-01  -0.057556
# 2011-02-01   0.021516
# 2011-03-01   0.039471
# ...               ...
# 2020-07-01   0.147114
# 2020-08-01   0.090461
# 2020-09-01  -0.087579
# 2020-10-01   0.018573
# 2020-10-19   0.000000
#
# [121 rows x 1 columns]

# %%
daily_pct_changes_amzn.hist(bins=50)

plt.show()

# %%
# FB
daily_close_fb = fb[['Adj Close']]

daily_pct_changes_fb = daily_close_fb.pct_change()

daily_pct_changes_fb.fillna(0, inplace=True)


daily_pct_changes_fb.hist(bins=50)

plt.show()

# %%
# GOOG
daily_close_goog = goog[['Adj Close']]

daily_pct_changes_goog = daily_close_goog.pct_change()

daily_pct_changes_goog.fillna(0, inplace=True)


daily_pct_changes_goog.hist(bins=50)

plt.show()

# %%
# AAPL
daily_close_aapl = aapl[['Adj Close']]

daily_pct_changes_aapl = daily_close_aapl.pct_change()

daily_pct_changes_aapl.fillna(0, inplace=True)


daily_pct_changes_aapl.hist(bins=50)

plt.show()

# %%
import seaborn as sns

sns.set()

# %%
# Set up the matplotlib figure
f, axes = plt.subplots(2, 2, figsize=(12, 7))

# Plot a simple histogram with binsize determined automatically
sns.distplot(daily_pct_changes_amzn['Adj Close'], color='r', ax=axes[0,0], axlabel='AMZN');

# Plot a kernel density estimate and rug plot
sns.distplot(daily_pct_changes_fb['Adj Close'], color='g', ax=axes[0,1], axlabel='FB');

# Plot a kernel density estimate and rug plot
sns.distplot(daily_pct_changes_goog['Adj Close'], color='b', ax=axes[1,0], axlabel='GOOG');

# Plot a kernel density estimate and rug plot
sns.distplot(daily_pct_changes_aapl['Adj Close'], color='y', ax=axes[1,1], axlabel='AAPL');
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ## Step 4: Volatality

# %%
import numpy as np

# %%
min_periods = 75

# Calculate the volatility
vol = daily_pct_changes_amzn.rolling(min_periods).std() * np.sqrt(min_periods)

vol.fillna(0, inplace=True)

vol
# Out:
#             Adj Close
# Date
# 2010-11-01   0.000000
# 2010-12-01   0.000000
# 2011-01-01   0.000000
# 2011-02-01   0.000000
# 2011-03-01   0.000000
# ...               ...
# 2020-07-01   0.733360
# 2020-08-01   0.735399
# 2020-09-01   0.745689
# 2020-10-01   0.742438
# 2020-10-19   0.741623
#
# [121 rows x 1 columns]

# %%
# Plot the volatility
vol.plot(figsize=(10, 8))

plt.show()

# %% [markdown]
# ## Rolling Means (Trends and Seasonality)

# %%
# AMZN
amzn_adj_close_px = amzn['Adj Close']

# Short moving window rolling mean
amzn['42'] = amzn_adj_close_px.rolling(window=42).mean()

# Lont moving window rolling mean
amzn['252'] = amzn_adj_close_px.rolling(window=252).mean()

# Plot the adjust closing price, the short and long windows of rolling means
amzn[['Adj Close', '42', '252']].plot(title='AMZN')

plt.show()

# %%
# FB
fb_adj_close_px = fb['Adj Close']

# Short moving window rolling mean
fb['42'] = fb_adj_close_px.rolling(window=42).mean()

# Lont moving window rolling mean
fb['252'] = fb_adj_close_px.rolling(window=252).mean()

# Plot the adjust closing price, the short and long windows of rolling means
fb[['Adj Close', '42', '252']].plot(title='FB')

plt.show()

# %%
# GOOG
goog_adj_close_px = goog['Adj Close']

# Short moving window rolling mean
goog['42'] = goog_adj_close_px.rolling(window=42).mean()

# Lont moving window rolling mean
goog['252'] = goog_adj_close_px.rolling(window=252).mean()

# Plot the adjust closing price, the short and long windows of rolling means
goog[['Adj Close', '42', '252']].plot(title='GOOG')

plt.show()

# %%
# AAPL
aapl_adj_close_px = goog['Adj Close']

# Short moving window rolling mean
aapl['42'] = aapl_adj_close_px.rolling(window=42).mean()

# Lont moving window rolling mean
aapl['252'] = aapl_adj_close_px.rolling(window=252).mean()

# Plot the adjust closing price, the short and long windows of rolling means
aapl[['Adj Close', '42', '252']].plot(title='AAPL')

plt.show()

# %%
amzn.loc['2020-01-01':'2020-10-19'][['Adj Close', '42', '252']].plot(title='AMZN in 2020');
fb.loc['2020-01-01':'2020-10-19'][['Adj Close', '42', '252']].plot(title='FB in 2020');
goog.loc['2020-01-01':'2020-10-19'][['Adj Close', '42', '252']].plot(title='GOOG in 2020');
aapl.loc['2020-01-01':'2020-10-19'][['Adj Close', '42', '252']].plot(title='AAPL in 2020');
